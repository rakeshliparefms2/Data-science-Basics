# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
t = sns.load_dataset('tips')
t.head(4)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2

# %%
sns.stripplot(x='time',y='total_bill',data=t,hue='sex')
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
'''Observations: 
1.The quantity of male and female are more for Dinner as compared to Lunch.
2.The Total bill is more during lunch.
3.The maximum total bill paid  during Lunch is by female and lowest total bill is paid by male.
4.The range of total bill paid by  maximum females during lunch is in between 10-20 , whereas by male its varying. 
5.The maximum total bill paid  during Dinner is by male and lowest total bill is paid by female.
6.The range of total bill paid by female during Dinner is varying  , whereas by maximum male its in between 10 to 30 . 
'''
# Out:
# 'Observations: \n1.The quantity of male and female are more for Dinner as compared to Lunch.\n2.The Total bill is more during lunch.\n3.The maximum total bill paid  during Lunch is by female and lowest total bill is paid by male.\n4.The range of total bill paid by  maximum females during lunch is in between 10-20 , whereas by male its varying. \n5.The maximum total bill paid  during Dinner is by male and lowest total bill is paid by female.\n6.The range of total bill paid by female during Dinner is varying  , whereas by maximum male its in between 10 to 30 . \n'

# %%
#load penguin dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
p=sns.load_dataset('penguins')
p.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
#check unique island
p.island.unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
#check columns

# %%
p.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
sns.stripplot(x='species',y ='body_mass_g',data=p)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.stripplot(x='species',y='body_mass_g',data=p,hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
p.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.stripplot(x='species',y='bill_depth_mm',data=p,hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_depth_mm'>

# %%
p.species.value_counts().plot(kind='pie',autopct='%.2f%%')
# Out:
# <AxesSubplot:ylabel='species'>

# %%
p.bill_depth_mm.value_counts().head(10).plot(kind='pie',autopct='%.f%%')
plt.figure(figsize=(125,125))

# %%
sns.stripplot(x='island',y='body_mass_g',data= p,hue='sex')
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %%
p.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.stripplot(data=p,x='sex',y='flipper_length_mm',hue='species')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='flipper_length_mm'>

# %%
#load tips dataset as t
t=sns.load_dataset('tips')
t.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#check some categorical columns
print(t.sex.unique())
t.sex.value_counts()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
t.smoker.unique()
# Out:
# ['No', 'Yes']
# Categories (2, object): ['Yes', 'No']

# %%
t.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
t.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
t.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
#day , time unique,info

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# check scatter plot with genderwise tip
t.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.stripplot(data=t,x='sex',y='tip',hue='smoker')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.stripplot(data=t,x='time',y='total_bill',hue='sex',palette='cool')
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
#genderwise total_bill
sns.stripplot(x='sex',y='tip',data=t)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.stripplot(x='size',y='total_bill',data=t,hue='sex')
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %% [markdown]
# # BOXPLOTS

# %%
sns.boxplot(x='day',y='total_bill',data=t)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=t,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(t['total_bill'])
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.stripplot(t['tip'])
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# # BAR PLOT

# %%
ti= sns.load_dataset('titanic')
ti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# check survival rate with respect to gender
sns.barplot(x='sex',y='survived',data=ti)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
ti[:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
sns.barplot(x='sex',y='survived',data=ti,hue='embark_town')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
ti.survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
ti.sex.value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
ti.survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
#hue=class
# check survival rate with respect to gender
sns.barplot(x='sex',y='survived',data=ti,hue='class')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
# embarked vs survived
#ti[:2]
print(ti.embarked.value_counts())
sns.barplot(x='embarked',y='survived',data=ti)
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64
# <AxesSubplot:xlabel='embarked', ylabel='survived'>

# %%
t[:2]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.barplot(x='size',y='total_bill',data=t)
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
mx=t.total_bill.max()
mx
# Out:
# 50.81

# %%
t[t.total_bill==mx]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3

# %%
t.total_bill.min()
# Out:
# 3.07

# %%
t[t.total_bill==t.total_bill.min()]
# Out:
#     total_bill  tip     sex smoker  day    time  size
# 67        3.07  1.0  Female    Yes  Sat  Dinner     1

# %%
t.total_bill.median()
# Out:
# 17.795

# %%
t[t.total_bill==t.total_bill.median()]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %% [markdown]
# # COUNT PLOT

# %%
ti[:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
sns.countplot(ti.survived)
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
sns.countplot(ti['class'])
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Classes',fontsize=20)
plt.ylabel('COUNT',fontsize=25)
sns.countplot(ti['class'])
plt.show()
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(x='sex',hue='class',data=ti,palette='cool_r')
#plt.legend('class')
#plt.legend(fontsize=10)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# # VIOLIN PLOT

# %%
ti[:3]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
ti.age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
#plt.figure(figsize=(15,25))
sns.violinplot(ti['age'])
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x='age',y='sex',data=ti,hue='class')
plt.xlabel('AGE',fontsize=15)
plt.ylabel('SEX',fontsize=15)
# Out:
# Text(0, 0.5, 'SEX')

# %%
sns.violinplot(x='sex',y='age',data=ti,hue='class')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# # HEATMAP

# %%
cr=ti.corr()
cr
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(cr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cr,annot=True,cmap='cool')
# Out:
# <AxesSubplot:>

# %%
cr.style.background_gradient("YlGnBu")
# Out:
# <style type="text/css">
# #T_edb66_row0_col0, #T_edb66_row1_col1, #T_edb66_row2_col2, #T_edb66_row3_col3, #T_edb66_row4_col4, #T_edb66_row5_col5, #T_edb66_row6_col6, #T_edb66_row7_col7 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_edb66_row0_col1, #T_edb66_row4_col6 {
#   background-color: #eaf7b1;
#   color: #000000;
# }
# #T_edb66_row0_col2 {
#   background-color: #d3eeb3;
#   color: #000000;
# }
# #T_edb66_row0_col3 {
#   background-color: #90d4b9;
#   color: #000000;
# }
# #T_edb66_row0_col4, #T_edb66_row1_col3, #T_edb66_row1_col6 {
#   background-color: #69c5be;
#   color: #000000;
# }
# #T_edb66_row0_col5, #T_edb66_row5_col0 {
#   background-color: #3bb0c3;
#   color: #f1f1f1;
# }
# #T_edb66_row0_col6, #T_edb66_row1_col2, #T_edb66_row1_col5, #T_edb66_row3_col7, #T_edb66_row4_col7, #T_edb66_row5_col1, #T_edb66_row6_col0, #T_edb66_row7_col3, #T_edb66_row7_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_edb66_row0_col7, #T_edb66_row5_col6 {
# ...

# %%
cr.style.background_gradient('cool')
# Out:
# <style type="text/css">
# #T_bfe63_row0_col0, #T_bfe63_row1_col1, #T_bfe63_row2_col2, #T_bfe63_row3_col3, #T_bfe63_row4_col4, #T_bfe63_row5_col5, #T_bfe63_row6_col6, #T_bfe63_row7_col7 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# #T_bfe63_row0_col1, #T_bfe63_row4_col6 {
#   background-color: #22ddff;
#   color: #000000;
# }
# #T_bfe63_row0_col2 {
#   background-color: #36c9ff;
#   color: #000000;
# }
# #T_bfe63_row0_col3 {
#   background-color: #58a7ff;
#   color: #f1f1f1;
# }
# #T_bfe63_row0_col4, #T_bfe63_row1_col3, #T_bfe63_row1_col6 {
#   background-color: #6b94ff;
#   color: #f1f1f1;
# }
# #T_bfe63_row0_col5, #T_bfe63_row5_col0 {
#   background-color: #857aff;
#   color: #f1f1f1;
# }
# #T_bfe63_row0_col6, #T_bfe63_row1_col2, #T_bfe63_row1_col5, #T_bfe63_row3_col7, #T_bfe63_row4_col7, #T_bfe63_row5_col1, #T_bfe63_row6_col0, #T_bfe63_row7_col3, #T_bfe63_row7_col4 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_bfe63_row0_col7, #T_bfe63_row5_col6 {
# ...

# %%
#check corr of few columns

# %%
ti1=ti.corr().iloc[:5,::2]
ti1
# Out:
#           survived       age     parch  adult_male
# survived  1.000000 -0.077221  0.081629   -0.557080
# pclass   -0.338481 -0.369226  0.018443    0.094035
# age      -0.077221  1.000000 -0.189119    0.280328
# sibsp    -0.035322 -0.308247  0.414838   -0.253586
# parch     0.081629 -0.189119  1.000000   -0.349943

# %%
plt.figure(figsize=(50,50))
sns.boxplot(x='age',y='parch',data=ti1,hue='survived')
# Out:
# <AxesSubplot:xlabel='age', ylabel='parch'>
