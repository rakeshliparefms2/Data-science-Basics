# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('matches.csv')
df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %% [markdown]
# # FETCH DATA OF FIRST THREE records

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#df.head(3)
df[:3]
# Out:
#    id    Season       city        date                team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017       Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
#df.tail(3)
df[-3:]
# Out:
#         id    Season           city        date                team1  \
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019  Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019       Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019       Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 753           0       Delhi Capitals            0               2
# 754           0  Chennai Super Kings            0               6
# 755           0       Mumbai Indians            1               0
#
#     player_of_match                               venue        umpire1  \
# 753         RR Pant                    ACA-VDCA Stadium            NaN
# ...

# %% [markdown]
# # how many rows and columns are there

# %%
df.shape
# Out:
# (756, 18)

# %%
print('The number of rows are',(df.shape)[0])
print('The number of columns are',(df.shape)[1])
# Out:
# The number of rows are 756
# The number of columns are 18

# %% [markdown]
# # CHECK ABSTRACT SUMMARY OF DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# # check missing values

# %%
b = pd.read_excel('book1.xlsx')
b[:3]
# Out:
#    SEGMENT_CODE OG_DIP_CODE  count$
# 0            AC         CAN     NaN
# 1            AC         CMP  4002.0
# 2           NaN         NaN    17.0

# %%
b.isna()
# Out:
#     SEGMENT_CODE  OG_DIP_CODE  count$
# 0          False        False    True
# 1          False        False   False
# 2           True         True   False
# 3          False         True   False
# 4           True        False    True
# 5          False        False   False
# 6          False        False   False
# 7          False        False    True

# %%
b.isna().sum()
# Out:
#  SEGMENT_CODE    2
# OG_DIP_CODE      2
# count$           3
# dtype: int64

# %%
df.isna()
# Out:
#         id  Season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 751  False   False  False  False  False  False        False          False
# 752  False   False  False  False  False  False        False          False
# 753  False   False  False  False  False  False        False          False
# 754  False   False  False  False  False  False        False          False
# 755  False   False  False  False  False  False        False          False
#
# ...

# %%
df.isna().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# #

# %% [markdown]
# # CHECK DESCRIPTIVE ANALYSIS

# %% [markdown]
# #

# %%
x = df.describe()
x
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %%
x.T
# Out:
#                 count         mean          std  min     25%    50%     75%  \
# id              756.0  1792.178571  3464.478148  1.0  189.75  378.5  567.25
# dl_applied      756.0     0.025132     0.156630  0.0    0.00    0.0    0.00
# win_by_runs     756.0    13.283069    23.471144  0.0    0.00    0.0   19.00
# win_by_wickets  756.0     3.350529     3.387963  0.0    0.00    4.0    6.00
#
#                     max
# id              11415.0
# dl_applied          1.0
# win_by_runs       146.0
# win_by_wickets     10.0

# %% [markdown]
# # CHECK DATA OF SPECIFIC COLUMNS

# %%
df[['city']]
# Out:
#               city
# 0        Hyderabad
# 1             Pune
# 2           Rajkot
# 3           Indore
# 4        Bangalore
# ..             ...
# 751         Mumbai
# 752        Chennai
# 753  Visakhapatnam
# 754  Visakhapatnam
# 755      Hyderabad
#
# [756 rows x 1 columns]

# %%
df[['city','result']]
# Out:
#               city  result
# 0        Hyderabad  normal
# 1             Pune  normal
# 2           Rajkot  normal
# 3           Indore  normal
# 4        Bangalore  normal
# ..             ...     ...
# 751         Mumbai  normal
# 752        Chennai  normal
# 753  Visakhapatnam  normal
# 754  Visakhapatnam  normal
# 755      Hyderabad  normal
#
# [756 rows x 2 columns]

# %%
df.loc[:,['city','result']]
# Out:
#               city  result
# 0        Hyderabad  normal
# 1             Pune  normal
# 2           Rajkot  normal
# 3           Indore  normal
# 4        Bangalore  normal
# ..             ...     ...
# 751         Mumbai  normal
# 752        Chennai  normal
# 753  Visakhapatnam  normal
# 754  Visakhapatnam  normal
# 755      Hyderabad  normal
#
# [756 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df.loc[:,'winner':'venue']
# Out:
#                           winner  win_by_runs  win_by_wickets player_of_match  \
# 0            Sunrisers Hyderabad           35               0    Yuvraj Singh
# 1         Rising Pune Supergiant            0               7       SPD Smith
# 2          Kolkata Knight Riders            0              10         CA Lynn
# 3                Kings XI Punjab            0               6      GJ Maxwell
# 4    Royal Challengers Bangalore           15               0       KM Jadhav
# ..                           ...          ...             ...             ...
# 751               Mumbai Indians            0               9       HH Pandya
# 752               Mumbai Indians            0               6        AS Yadav
# 753               Delhi Capitals            0               2         RR Pant
# 754          Chennai Super Kings            0               6    F du Plessis
# 755               Mumbai Indians            1               0       JJ Bumrah
#
# ...

# %%
b.loc[:,:]
# Out:
#    SEGMENT_CODE OG_DIP_CODE  count$
# 0            AC         CAN     NaN
# 1            AC         CMP  4002.0
# 2           NaN         NaN    17.0
# 3           ARB         NaN   339.0
# 4           NaN         CAN     NaN
# 5           BSD         CMP  1470.0
# 6          CHAT         CAN    18.0
# 7          CHAT         CMP     NaN

# %%
b.loc[:,[' SEGMENT_CODE','count$']]
# Out:
#    SEGMENT_CODE  count$
# 0            AC     NaN
# 1            AC  4002.0
# 2           NaN    17.0
# 3           ARB   339.0
# 4           NaN     NaN
# 5           BSD  1470.0
# 6          CHAT    18.0
# 7          CHAT     NaN

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
win = df.loc[:,['winner','toss_winner','venue']]
win[:20]
# Out:
#                          winner                  toss_winner  \
# 0           Sunrisers Hyderabad  Royal Challengers Bangalore
# 1        Rising Pune Supergiant       Rising Pune Supergiant
# 2         Kolkata Knight Riders        Kolkata Knight Riders
# 3               Kings XI Punjab              Kings XI Punjab
# 4   Royal Challengers Bangalore  Royal Challengers Bangalore
# 5           Sunrisers Hyderabad          Sunrisers Hyderabad
# 6                Mumbai Indians               Mumbai Indians
# 7               Kings XI Punjab  Royal Challengers Bangalore
# 8              Delhi Daredevils       Rising Pune Supergiant
# 9                Mumbai Indians               Mumbai Indians
# 10        Kolkata Knight Riders        Kolkata Knight Riders
# 11               Mumbai Indians               Mumbai Indians
# 12                Gujarat Lions                Gujarat Lions
# 13        Kolkata Knight Riders          Sunrisers Hyderabad
# ...

# %%
win[win.winner == win.toss_winner]
# Out:
#                           winner                  toss_winner  \
# 1         Rising Pune Supergiant       Rising Pune Supergiant
# 2          Kolkata Knight Riders        Kolkata Knight Riders
# 3                Kings XI Punjab              Kings XI Punjab
# 4    Royal Challengers Bangalore  Royal Challengers Bangalore
# 5            Sunrisers Hyderabad          Sunrisers Hyderabad
# ..                           ...                          ...
# 750              Kings XI Punjab              Kings XI Punjab
# 751               Mumbai Indians               Mumbai Indians
# 753               Delhi Capitals               Delhi Capitals
# 754          Chennai Super Kings          Chennai Super Kings
# 755               Mumbai Indians               Mumbai Indians
#
#                                          venue
# 1      Maharashtra Cricket Association Stadium
# 2       Saurashtra Cricket Association Stadium
# 3                       Holkar Cricket Stadium
# ...

# %% [markdown]
# # FETCH DATA OF 2017

# %%
df.Season.str.split('-',expand =True)[1]
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 751    2019
# 752    2019
# 753    2019
# 754    2019
# 755    2019
# Name: 1, Length: 756, dtype: object

# %%
df['year']=df.Season.str.split('-',expand=True)[1]
df['year']
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 751    2019
# 752    2019
# 753    2019
# 754    2019
# 755    2019
# Name: year, Length: 756, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3', 'year'],
#       dtype='object')

# %%
df[df.year == '2017']
# Out:
#     id    Season        city        date                        team1  \
# 0    1  IPL-2017   Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1    2  IPL-2017        Pune  06-04-2017               Mumbai Indians
# 2    3  IPL-2017      Rajkot  07-04-2017                Gujarat Lions
# 3    4  IPL-2017      Indore  08-04-2017       Rising Pune Supergiant
# 4    5  IPL-2017   Bangalore  08-04-2017  Royal Challengers Bangalore
# 5    6  IPL-2017   Hyderabad  09-04-2017                Gujarat Lions
# 6    7  IPL-2017      Mumbai  09-04-2017        Kolkata Knight Riders
# 7    8  IPL-2017      Indore  10-04-2017  Royal Challengers Bangalore
# 8    9  IPL-2017        Pune  11-04-2017             Delhi Daredevils
# 9   10  IPL-2017      Mumbai  12-04-2017          Sunrisers Hyderabad
# 10  11  IPL-2017     Kolkata  13-04-2017              Kings XI Punjab
# 11  12  IPL-2017   Bangalore  14-04-2017  Royal Challengers Bangalore
# ...

# %%
df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %% [markdown]
# # How many matches played in season 2018

# %%
s = df[df.year == '2018'].shape
s
# Out:
# (60, 19)

# %%
print('The number of matches played in 2018 is :',s[0])
# Out:
# The number of matches played in 2018 is : 60

# %%
s[1]
# Out:
# 19

# %% [markdown]
# # How many matches played at Rajiv Gandhi International Stadium, Uppal

# %%
df.venue
# Out:
# 0      Rajiv Gandhi International Stadium, Uppal
# 1        Maharashtra Cricket Association Stadium
# 2         Saurashtra Cricket Association Stadium
# 3                         Holkar Cricket Stadium
# 4                          M Chinnaswamy Stadium
#                          ...
# 751                             Wankhede Stadium
# 752                    M. A. Chidambaram Stadium
# 753                             ACA-VDCA Stadium
# 754                             ACA-VDCA Stadium
# 755           Rajiv Gandhi Intl. Cricket Stadium
# Name: venue, Length: 756, dtype: object

# %%
s = df[df.venue =='Rajiv Gandhi International Stadium, Uppal'].shape
s
# Out:
# (56, 19)

# %%
print('The number of venue of UPPAL ARE :',s[0])
# Out:
# The number of venue of UPPAL ARE : 56

# %% [markdown]
# # Show the total seasons in dataset

# %%
df.Season.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 756 entries, 0 to 755
# Series name: Season
# Non-Null Count  Dtype
# --------------  -----
# 756 non-null    object
# dtypes: object(1)
# memory usage: 6.0+ KB

# %%
s = (df[df.year == '2017'].shape)[0]
print('The number of matches in 2017:', s)
# Out:
# The number of matches in 2017: 59

# %%
s1 =(df[df.year == '2018'].shape)[0]
print('The number of matches in 2018:', s1)
# Out:
# The number of matches in 2018: 60

# %%
s2 =(df[df.year == '2019'].shape)[0]
print('The number of matches in 2019:', s1)
# Out:
# The number of matches in 2019: 60

# %%
s3 =(df[df.year == '2020'].shape)[0]
print('The number of matches in 2020:', s3)
# Out:
# The number of matches in 2020: 0

# %%
s4 =(df[df.year == '2021'].shape)[0]
print('The number of matches in 2020:', s4)
# Out:
# The number of matches in 2020: 0

# %%
s0 =(df[df.year == '2016'].shape)[0]
print('The number of matches in 2016:', s0)
# Out:
# The number of matches in 2016: 60

# %%
s5 =(df[df.year == '2015'].shape)[0]
print('The number of matches in 2015:', s5)
# Out:
# The number of matches in 2015: 59

# %%
s6 =(df[df.year == '2014'].shape)[0]
print('The number of matches in 2014:', s6)
# Out:
# The number of matches in 2014: 60

# %%
s7 =(df[df.year == '2013'].shape)[0]
print('The number of matches in 2013:', s7)
# Out:
# The number of matches in 2013: 76

# %%
s8 =(df[df.year == '2012'].shape)[0]
print('The number of matches in 2012:', s8)
# Out:
# The number of matches in 2012: 74

# %%
s9 =(df[df.year == '2011'].shape)[0]
print('The number of matches in 2011:', s9)
# Out:
# The number of matches in 2011: 73

# %%
s10 =(df[df.year == '2010'].shape)[0]
print('The number of matches in 2010:', s10)
# Out:
# The number of matches in 2010: 60

# %%
s11 =(df[df.year == '2009'].shape)[0]
print('The number of matches in 2009:', s11)
# Out:
# The number of matches in 2009: 57

# %%
s12 =(df[df.year == '2008'].shape)[0]
 print('The number of matches in 2008:', s12)
# Out:
# The number of matches in 2008: 58

# %%
s13 =(df[df.year == '2007'].shape)[0]
print('The number of matches in 2007:', s13)
# Out:
# The number of matches in 2007: 0

# %%
s0+s+s1+s2+s4+s5+s6+s7+s8+s9+s10+s11+s12+s13
# Out:
# 756

# %%
df.info
# Out:
# <bound method DataFrame.info of         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
x = df.sort_values(by='year')
x
# Out:
#         id    Season        city        date                  team1  \
# 116    117  IPL-2008      Mumbai  01-06-2008    Chennai Super Kings
# 82      83  IPL-2008      Jaipur  04-05-2008    Chennai Super Kings
# 81      82  IPL-2008      Mumbai  04-05-2008         Mumbai Indians
# 80      81  IPL-2008  Chandigarh  03-05-2008        Kings XI Punjab
# 79      80  IPL-2008   Hyderabad  25-05-2008        Deccan Chargers
# ..     ...       ...         ...         ...                    ...
# 721  11317  IPL-2019     Kolkata  12-04-2019  Kolkata Knight Riders
# 722  11318  IPL-2019      Mumbai  13-04-2019         Mumbai Indians
# 723  11319  IPL-2019      Mohali  13-04-2019        Kings XI Punjab
# 725  11321  IPL-2019   Hyderabad  14-04-2019         Delhi Capitals
# 755  11415  IPL-2019   Hyderabad  12-05-2019         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
(x[x.year == '20']).describe()
# Out:
#         id  dl_applied  win_by_runs  win_by_wickets
# count  0.0         0.0          0.0             0.0
# mean   NaN         NaN          NaN             NaN
# std    NaN         NaN          NaN             NaN
# min    NaN         NaN          NaN             NaN
# 25%    NaN         NaN          NaN             NaN
# 50%    NaN         NaN          NaN             NaN
# 75%    NaN         NaN          NaN             NaN
# max    NaN         NaN          NaN             NaN

# %%
x.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %%
x.arange(2008,2020)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [118], in <cell line: 1>()
# ----> 1 x.arange(2008,2020)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'arange'

# %%
x1 = x.year
x1
# Out:
# 116    2008
# 82     2008
# 81     2008
# 80     2008
# 79     2008
#        ...
# 721    2019
# 722    2019
# 723    2019
# 725    2019
# 755    2019
# Name: year, Length: 756, dtype: object

# %%
(x.year).describe()
# Out:
# count      756
# unique      12
# top       2013
# freq        76
# Name: year, dtype: object

# %%
x2 = x1.values.flatten()
x2
# Out:
# array(['2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008',
#        '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008',
#        '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008',
#        '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008',
#        '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008',
#        '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008',
#        '2008', '2008', '2008', '2008', '2008', '2008', '2008', '2008',
#        '2008', '2008', '2009', '2009', '2009', '2009', '2009', '2009',
#        '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009',
#        '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009',
#        '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009',
#        '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009',
#        '2009', '2009', '2009', '2009', '2009', '2009', '2009', '2009',
# ...

# %%
xx = set(x2)
xx
# Out:
# {'2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019'}

# %%
len(xx)
# Out:
# 12

# %%
len(x2)
# Out:
# 756
