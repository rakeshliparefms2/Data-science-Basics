# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # DATA VISUALISATION

# %% [markdown]
# ### VISUAL ANALYSIS

# %%
'''It consists of mainly 3 types :
1) Univariate Analysis
2) Bivariate Analysis
3) Multivariate Analysis
'''

# %% [markdown]
# # Scatter Plot

# %%
a = np.random.random(20)
a
# Out:
# array([0.14731444, 0.72981909, 0.30995703, 0.96352753, 0.66659929,
#        0.48359686, 0.19419819, 0.82479258, 0.78557305, 0.7700631 ,
#        0.28164206, 0.10467727, 0.17599073, 0.40455269, 0.33552163,
#        0.53075311, 0.56844191, 0.16288255, 0.06728308, 0.36407318])

# %%
range(59)
# Out:
# range(0, 59)

# %%
plt.plot(range(59),a)

# %%
plt.scatter(range(20),a)

# %% [markdown]
# #how to do int of x axis

# %%
plt.scatter(range(1,21),a)
plt.xticks(range(1,21),list(range(1,21)))
plt.show()

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
bp = np.random.randint(50,180,100)
bp
# Out:
# array([111, 121, 132, 165, 174, 152, 107,  88, 117, 173,  90,  97, 161,
#         81, 147,  56,  69, 139, 111, 107,  74,  51,  68,  63, 138,  78,
#        178,  64,  94,  89, 103,  63, 145,  93,  81, 124,  67,  92,  70,
#        112,  52, 128,  66,  80, 129, 142,  89, 164, 109, 131,  78,  73,
#        162, 142,  65, 120,  76, 173, 131,  76, 163, 151, 142,  70,  99,
#         67, 141,  70, 136, 128,  87,  73, 167,  55,  53, 128, 101,  60,
#        121, 104,  53,  59,  55,  93, 111, 126, 135, 159,  98,  83, 124,
#         55, 171,  82, 166, 178, 173, 109, 148, 145])

# %%
bp.sort()
bp
# Out:
# array([ 51,  52,  53,  53,  55,  55,  55,  56,  59,  60,  63,  63,  64,
#         65,  66,  67,  67,  68,  69,  70,  70,  70,  73,  73,  74,  76,
#         76,  78,  78,  80,  81,  81,  82,  83,  87,  88,  89,  89,  90,
#         92,  93,  93,  94,  97,  98,  99, 101, 103, 104, 107, 107, 109,
#        109, 111, 111, 111, 112, 117, 120, 121, 121, 124, 124, 126, 128,
#        128, 128, 129, 131, 131, 132, 135, 136, 138, 139, 141, 142, 142,
#        142, 145, 145, 147, 148, 151, 152, 159, 161, 162, 163, 164, 165,
#        166, 167, 171, 173, 173, 173, 174, 178, 178])

# %%
bp.min()
# Out:
# 51

# %%
bp.max()
# Out:
# 178

# %%
plt.hist(bp)
# Out:
# (array([12., 15., 11.,  9., 10.,  7., 11., 10.,  6.,  9.]),
#  array([ 51. ,  63.7,  76.4,  89.1, 101.8, 114.5, 127.2, 139.9, 152.6,
#         165.3, 178. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(bp,range=(80,120))
# Out:
# (array([5., 1., 4., 4., 3., 2., 3., 5., 1., 2.]),
#  array([ 80.,  84.,  88.,  92.,  96., 100., 104., 108., 112., 116., 120.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(bp,range(80,121))
# Out:
# (array([1., 2., 1., 1., 0., 0., 0., 1., 1., 2., 1., 0., 1., 2., 1., 0., 0.,
#         1., 1., 1., 0., 1., 0., 1., 1., 0., 0., 2., 0., 2., 0., 3., 1., 0.,
#         0., 0., 0., 1., 0., 1.]),
#  array([ 80,  81,  82,  83,  84,  85,  86,  87,  88,  89,  90,  91,  92,
#          93,  94,  95,  96,  97,  98,  99, 100, 101, 102, 103, 104, 105,
#         106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118,
#         119, 120]),
#  <BarContainer object of 40 artists>)

# %%
plt.hist(bp,bins=[80,90,100,110,120],rwidth=0.96)
# Out:
# (array([9., 8., 7., 6.]),
#  array([ 80,  90, 100, 110, 120]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(bp,bins=[50,60,70,80,120,130,140,150,160,170,180],rwidth=0.96)
# Out:
# (array([ 9., 10., 10., 29., 10.,  7.,  8.,  3.,  7.,  7.]),
#  array([ 50,  60,  70,  80, 120, 130, 140, 150, 160, 170, 180]),
#  <BarContainer object of 10 artists>)
