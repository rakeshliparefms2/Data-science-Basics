# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
a = np.random.randint(50,150,150)
a
# Out:
# array([ 54,  94, 146,  63,  87,  51, 107, 138, 144, 137, 100,  76, 123,
#         93, 146, 127,  86,  52, 132, 110, 135, 133,  93, 118,  82,  52,
#        145, 103, 129,  79,  69,  60, 140,  51, 114, 116, 137,  59,  86,
#        137, 103, 146,  57,  98,  70,  56, 113, 102,  86, 139, 122, 137,
#         78, 104, 121,  98,  88,  66,  64,  67,  78,  90, 114, 143,  83,
#         82,  51, 149,  85, 129, 105,  86,  65,  87, 113,  86, 129,  82,
#         70,  55, 109,  54, 132, 121,  57,  88, 122,  60, 100,  80, 110,
#        120,  89,  91, 106, 103,  57, 114, 142,  52, 114, 134,  54, 113,
#         57, 146, 108,  76,  64,  75,  67,  94,  69, 142,  93,  55,  52,
#        142, 146, 131, 147, 106, 109, 135,  79, 119,  55,  94, 104,  59,
#         59,  58, 118, 107,  70,  51, 102,  99, 123,  84, 149,  96,  61,
#        114,  78,  74,  73, 107, 123, 104])

# %%
plt.hist(a,bins=6,rwidth = 0.96)
# Out:
# (array([33., 20., 24., 30., 18., 25.]),
#  array([ 51.        ,  67.33333333,  83.66666667, 100.        ,
#         116.33333333, 132.66666667, 149.        ]),
#  <BarContainer object of 6 artists>)

# %%
plt.hist(a,bins=[50,60,70,80,120,130,140,150],rwidth=0.95)
plt.show()

# %%
plt.hist(a,bins=6,color='r',alpha=0.7)
plt.show()

# %%
states=['MH','HR','AP','KA','GA','UP']
covid=[125,89,235,165,45,384]

# %%
plt.pie(covid,labels=states,autopct='%.2f%%')
plt.show()

# %%
plt.pie(covid,labels=states,autopct='%.f%%',explode=[0.1,0,0,0,0,0.2])
plt.show()

# %%
age=[12,42,26,27,11,53,34,36,37,56,29,26]

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.boxplot(age)
plt.show()

# %%
age=[12,42,26,27,11,53,34,36,37,56,29,26,200]

# %%
plt.boxplot(age)
plt.show()

# %% [markdown]
# # PLT.SUBPLOT

# %%
x = np.linspace(1,20,120)
y = np.sin (x)
z = np.cos (x)

# %%
a = np.random.randint(50,150,200)
a
# Out:
# array([129,  93,  58, 124,  54,  80, 119, 107, 101,  78,  61,  92, 117,
#        131,  97, 149,  76, 138,  95,  74, 132,  89,  98, 129, 112, 139,
#         91,  89,  94, 140,  68, 147, 107,  77, 112,  87, 101, 133, 138,
#         92,  91,  69,  90,  60, 130, 128, 100,  68,  83,  98, 105, 116,
#        144,  96, 101,  82, 113,  86,  93,  76, 130, 128, 145, 148,  84,
#        132, 143, 127,  54, 137,  98,  81, 146, 136,  96,  65,  73, 130,
#         74, 141, 111, 112, 109,  78, 142, 134,  80,  60, 142, 137, 133,
#         81, 134, 133, 108, 133,  60, 141, 149,  67, 113, 106,  57,  61,
#         62, 112, 117,  69,  61, 145,  51, 111, 130, 120,  74,  87, 138,
#         99,  62, 119,  87, 140,  99,  92,  69,  53,  94, 111, 109,  66,
#         95, 133,  68,  82, 122, 137,  53,  52,  63, 141, 109, 129,  65,
#        124,  74,  58,  80,  61, 126, 101,  56,  95,  79, 133,  89, 116,
#        109, 127, 118,  99, 107, 131, 141, 143, 140,  67,  96, 133, 139,
# ...

# %%
br = ['ME','CS','CE','EE','E&TC','DS','TRONICS']
adm = [200,280,100,80,85,350,75]

# %%
marks = [85,95,92,87,89,65,75,73,74,66,84,69,68,59,23,11,29,64]

# %%
plt.subplot(221)
plt.subplot(222)
plt.subplot(223)
plt.subplot(224)
# Out:
# <AxesSubplot:>

# %%
plt.subplot(221)
plt.plot(x,z,linestyle='--')

plt.subplot(222)
plt.hist(a,bins=[50,60,70,80,120,130,140,150],rwidth=0.96)

plt.subplot(223)
plt.pie(adm,labels=br,autopct= '%.2f%%',explode=[0,0,0,0,0,0.2,0])

plt.subplot(224)
plt.boxplot(marks)
plt.show()
