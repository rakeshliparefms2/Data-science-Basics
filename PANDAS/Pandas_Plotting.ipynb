# %% [markdown]
# import numpy as np
# import pandas as pd

# %%
import numpy as np
import pandas as pd

# %%
df = np.random.random((4,5))
df
# Out:
# array([[0.41859327, 0.17684745, 0.21380669, 0.66453209, 0.88075834],
#        [0.5575064 , 0.12293311, 0.42674531, 0.90901972, 0.77246007],
#        [0.99643206, 0.36079691, 0.79777218, 0.34556335, 0.01844838],
#        [0.5589183 , 0.11341769, 0.06461905, 0.87945067, 0.33339045]])

# %%
df.resize((5,4))

# %%
df
# Out:
# array([[0.41859327, 0.17684745, 0.21380669, 0.66453209],
#        [0.88075834, 0.5575064 , 0.12293311, 0.42674531],
#        [0.90901972, 0.77246007, 0.99643206, 0.36079691],
#        [0.79777218, 0.34556335, 0.01844838, 0.5589183 ],
#        [0.11341769, 0.06461905, 0.87945067, 0.33339045]])

# %%
d = pd.DataFrame(df,columns=['val1','val2','val3','val4'])
d
# Out:
#        val1      val2      val3      val4
# 0  0.418593  0.176847  0.213807  0.664532
# 1  0.880758  0.557506  0.122933  0.426745
# 2  0.909020  0.772460  0.996432  0.360797
# 3  0.797772  0.345563  0.018448  0.558918
# 4  0.113418  0.064619  0.879451  0.333390

# %%
d['val2']
# Out:
# 0    0.176847
# 1    0.557506
# 2    0.772460
# 3    0.345563
# 4    0.064619
# Name: val2, dtype: float64

# %%
d.val4
# Out:
# 0    0.664532
# 1    0.426745
# 2    0.360797
# 3    0.558918
# 4    0.333390
# Name: val4, dtype: float64

# %%
d.val3.plot()
# Out:
# <AxesSubplot:>

# %%
d.plot()
# Out:
# <AxesSubplot:>

# %%
d.plot(subplots=True,figsize=(15,15),layout=(2,2))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
d.plot.bar()
# Out:
# <AxesSubplot:>

# %%
d.val3.plot.barh()
# Out:
# <AxesSubplot:>

# %%
d.plot.bar(subplots = True, figsize=(15,15),layout=(2,2))
# Out:
# array([[<AxesSubplot:title={'center':'val1'}>,
#         <AxesSubplot:title={'center':'val2'}>],
#        [<AxesSubplot:title={'center':'val3'}>,
#         <AxesSubplot:title={'center':'val4'}>]], dtype=object)

# %%
d.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
d.plot.bar()
# Out:
# <AxesSubplot:>

# %%
d.plot.bar(subplots=True,figsize=(15,15),layout=(2,2),color=['b','r','m','g'])
# Out:
# array([[<AxesSubplot:title={'center':'val1'}>,
#         <AxesSubplot:title={'center':'val2'}>],
#        [<AxesSubplot:title={'center':'val3'}>,
#         <AxesSubplot:title={'center':'val4'}>]], dtype=object)

# %% [markdown]
# # Scatter Plot

# %%
d.plot.scatter('val2','val4')
# Out:
# <AxesSubplot:xlabel='val2', ylabel='val4'>

# %%
d.plot('val1','val2',kind='scatter')
# Out:
# <AxesSubplot:xlabel='val1', ylabel='val2'>

# %%
d.plot.scatter('val1','val2')
# Out:
# <AxesSubplot:xlabel='val1', ylabel='val2'>

# %% [markdown]
# # Pie Chart

# %%
d.plot(kind='pie',subplots = True,figsize=(25,25),autopct='%.2f%%',fontsize=15,layout=(2,2))
# Out:
# array([[<AxesSubplot:ylabel='val1'>, <AxesSubplot:ylabel='val2'>],
#        [<AxesSubplot:ylabel='val3'>, <AxesSubplot:ylabel='val4'>]],
#       dtype=object)

# %%
d.val2.plot(kind='pie', autopct='%.2f%%',explode=[0,0,0.1,0,0])
# Out:
# <AxesSubplot:ylabel='val2'>

# %%
d
# Out:
#        val1      val2      val3      val4
# 0  0.418593  0.176847  0.213807  0.664532
# 1  0.880758  0.557506  0.122933  0.426745
# 2  0.909020  0.772460  0.996432  0.360797
# 3  0.797772  0.345563  0.018448  0.558918
# 4  0.113418  0.064619  0.879451  0.333390

# %% [markdown]
# # Hist plot

# %%
d.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
d.val2.plot.hist(bins=[0.3,0.4,0.5])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
d.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'val1'}>,
#         <AxesSubplot:title={'center':'val2'}>],
#        [<AxesSubplot:title={'center':'val3'}>,
#         <AxesSubplot:title={'center':'val4'}>]], dtype=object)

# %%
d
# Out:
#        val1      val2      val3      val4
# 0  0.418593  0.176847  0.213807  0.664532
# 1  0.880758  0.557506  0.122933  0.426745
# 2  0.909020  0.772460  0.996432  0.360797
# 3  0.797772  0.345563  0.018448  0.558918
# 4  0.113418  0.064619  0.879451  0.333390

# %% [markdown]
# # Area Plot

# %%
d.plot(kind='area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # BOXPLOT

# %%
d.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
d.val3.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # kernel density estimation plot [KDE]

# %%
d.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
d
# Out:
#        val1      val2      val3      val4
# 0  0.418593  0.176847  0.213807  0.664532
# 1  0.880758  0.557506  0.122933  0.426745
# 2  0.909020  0.772460  0.996432  0.360797
# 3  0.797772  0.345563  0.018448  0.558918
# 4  0.113418  0.064619  0.879451  0.333390

# %%
d.val3.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
x = pd.Series([1,25,4,25,69,7,57,57,100,100,10,10,10,10,10,10,10,10,10,10,6,6,6,88,88,8,8,8,1,1,11,1,1,1,1,22,2,2,2,])
x.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
x1 = pd.Series([23,235,69,-95,5,-77,-55,67,122,257,-27])
x1.plot.barh()
# Out:
# <AxesSubplot:>
