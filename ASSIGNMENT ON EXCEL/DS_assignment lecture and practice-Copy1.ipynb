# %%
import numpy as np #numeric operations
import pandas as pd #data analysis
import matplotlib.pyplot as plt # data visulization

# %%
# load dataset using pandas
df = pd.read_excel('batch_19.xlsx')
df #dataframe
# Out:
#     Sr. No             Name    Place     Post  Salary    Code
# 0        1    Akshay Bankar      Pune      DS   67000  AK-102
# 1        2      Arati Banne   Solapur      SE   56000  AB-304
# 2        3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3        4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4        5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5        6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6        7    Piyush Sawant    Mumbai      SE   89000      PS
# 7        8     Umesh Thorat      Pune      SE   67000  UT-102
# 8        9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9       10    Supriya Gurav      Pune      SE   90000  SG-100
# 10      11    Shital Shelar     Karad  Tester   80000  SS-222

# %% [markdown]
# ## How many records u have

# %%
df.shape
#(rows,columns)
# Out:
# (11, 6)

# %% [markdown]
# ## List out the columns

# %%
df.columns
# Out:
# Index(['Sr. No', 'Name', 'Place ', 'Post', 'Salary', 'Code'], dtype='object')

# %% [markdown]
# ## Check the data types of each column

# %%
df.dtypes
# Out:
# Sr. No     int64
# Name      object
# Place     object
# Post      object
# Salary     int64
# Code      object
# dtype: object

# %%
# Select only name and place
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['Sr. No', 'Name', 'Place ', 'Post', 'Salary', 'Code'], dtype='object')

# %%
# as u can see in column name Place we have extra space at the end . 
#so please remove that space
df = df.rename(columns={'Place ':'Place','Sr. No':'Sr_No'})
df
# Out:
#     Sr_No             Name     Place    Post  Salary    Code
# 0       1    Akshay Bankar      Pune      DS   67000  AK-102
# 1       2      Arati Banne   Solapur      SE   56000  AB-304
# 2       3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3       4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4       5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5       6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6       7    Piyush Sawant    Mumbai      SE   89000      PS
# 7       8     Umesh Thorat      Pune      SE   67000  UT-102
# 8       9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9      10    Supriya Gurav      Pune      SE   90000  SG-100
# 10     11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
#check new column names
df.columns
# Out:
# Index(['Sr_No', 'Name', 'Place', 'Post', 'Salary', 'Code'], dtype='object')

# %%
df[['Name','Place']]
# Out:
#                Name     Place
# 0     Akshay Bankar      Pune
# 1       Arati Banne   Solapur
# 2      Dipak Sawant  Kolhapur
# 3     Ganesh Rakate    Sangli
# 4   Harshala Gondal    Sangli
# 5      Kuldip Muley      Beed
# 6     Piyush Sawant    Mumbai
# 7      Umesh Thorat      Pune
# 8     Vaibhav Ladge  Kolhapur
# 9     Supriya Gurav      Pune
# 10    Shital Shelar     Karad

# %%
# if above data we want to convert into array
np.array(df[['Name','Place']])
# Out:
# array([['Akshay Bankar', 'Pune'],
#        ['Arati Banne', 'Solapur'],
#        ['Dipak Sawant', 'Kolhapur'],
#        ['Ganesh Rakate', 'Sangli'],
#        ['Harshala Gondal', 'Sangli'],
#        ['Kuldip Muley', 'Beed'],
#        ['Piyush Sawant', 'Mumbai'],
#        ['Umesh Thorat', 'Pune'],
#        ['Vaibhav Ladge', 'Kolhapur'],
#        ['Supriya Gurav', 'Pune'],
#        ['Shital Shelar', 'Karad']], dtype=object)

# %% [markdown]
# # Please give average salary

# %%
df.Salary.mean()
# Out:
# 78090.90909090909

# %%
round(df.Salary.mean())
# Out:
# 78091

# %%
round(df.Salary.mean(),2)
# Out:
# 78090.91

# %%
# Count the employee Placewise
df.Place.value_counts()
# Out:
# Pune        3
# Kolhapur    2
# Sangli      2
# Solapur     1
# Beed        1
# Mumbai      1
# Karad       1
# Name: Place, dtype: int64

# %%
# plot above data
df.Place.value_counts().plot(kind='barh',color='r')
plt.title('Placewise employee count')
plt.xlabel('City')
plt.ylabel('Count')
plt.grid()
plt.savefig('countP.png',dpi=250)

# %%
# lets fetch data of Pune people 
df.query('Place=="Pune"')
# Out:
#    Sr_No           Name Place Post  Salary    Code
# 0      1  Akshay Bankar  Pune   DS   67000  AK-102
# 7      8   Umesh Thorat  Pune   SE   67000  UT-102
# 9     10  Supriya Gurav  Pune   SE   90000  SG-100

# %%
# Punekar wants there own separate file
df.query('Place=="Pune"').to_csv('Punekar.csv',index=False)

# %%
# I want Average salary given to employee from Sangli and Pune region
df.query('Place=="Pune" or Place=="Sangli"')
# Out:
#    Sr_No             Name   Place Post  Salary    Code
# 0      1    Akshay Bankar    Pune   DS   67000  AK-102
# 3      4    Ganesh Rakate  Sangli   HR   80000  GR-450
# 4      5  Harshala Gondal  Sangli   DS   45000  HG-232
# 7      8     Umesh Thorat    Pune   SE   67000  UT-102
# 9     10    Supriya Gurav    Pune   SE   90000  SG-100

# %%
df.query('Place=="Pune" or Place=="Sangli"').Salary
# Out:
# 0    67000
# 3    80000
# 4    45000
# 7    67000
# 9    90000
# Name: Salary, dtype: int64

# %%
df.query('Place=="Pune" or Place=="Sangli"').Salary.mean()
# Out:
# 69800.0

# %%
# Who gets maximum salary
df.Salary.max()
# Out:
# 120000

# %%
df.query('Salary==120000')
# Out:
#    Sr_No          Name Place Post  Salary    Code
# 5      6  Kuldip Muley  Beed  CEO  120000  KM-333

# %%
df ]
# Out:
#    Sr_No          Name Place Post  Salary    Code
# 5      6  Kuldip Muley  Beed  CEO  120000  KM-333

# %%
df.sort_values(by='Post')
# Out:
#     Sr_No             Name     Place    Post  Salary    Code
# 2       3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 5       6     Kuldip Muley      Beed     CEO  120000  KM-333
# 0       1    Akshay Bankar      Pune      DS   67000  AK-102
# 4       5  Harshala Gondal    Sangli      DS   45000  HG-232
# 3       4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 1       2      Arati Banne   Solapur      SE   56000  AB-304
# 6       7    Piyush Sawant    Mumbai      SE   89000      PS
# 7       8     Umesh Thorat      Pune      SE   67000  UT-102
# 9      10    Supriya Gurav      Pune      SE   90000  SG-100
# 8       9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 10     11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df
# Out:
#     Sr_No             Name     Place    Post  Salary    Code
# 0       1    Akshay Bankar      Pune      DS   67000  AK-102
# 1       2      Arati Banne   Solapur      SE   56000  AB-304
# 2       3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3       4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4       5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5       6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6       7    Piyush Sawant    Mumbai      SE   89000      PS
# 7       8     Umesh Thorat      Pune      SE   67000  UT-102
# 8       9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9      10    Supriya Gurav      Pune      SE   90000  SG-100
# 10     11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
import numpy as np #numeric operations
import pandas as pd #data analysis
import matplotlib.pyplot as plt # data visulization

# load dataset using pandas
df = pd.read_excel('batch__19.xlsx')
df #dataframe
# Out:
#     Sr. No             Name    Place     Post  Salary    Code
# 0        1    Akshay Bankar      Pune      DS   67000  AK-102
# 1        2      Arati Banne   Solapur      SE   56000  AB-304
# 2        3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3        4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4        5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5        6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6        7    Piyush Sawant    Mumbai      SE   89000      PS
# 7        8     Umesh Thorat      Pune      SE   67000  UT-102
# 8        9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9       10    Supriya Gurav      Pune      SE   90000  SG-100
# 10      11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df
# Out:
#     Sr. No             Name    Place     Post  Salary    Code
# 0        1    Akshay Bankar      Pune      DS   67000  AK-102
# 1        2      Arati Banne   Solapur      SE   56000  AB-304
# 2        3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3        4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4        5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5        6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6        7    Piyush Sawant    Mumbai      SE   89000      PS
# 7        8     Umesh Thorat      Pune      SE   67000  UT-102
# 8        9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9       10    Supriya Gurav      Pune      SE   90000  SG-100
# 10      11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df
# Out:
#     Sr. No             Name    Place     Post  Salary    Code
# 0        1    Akshay Bankar      Pune      DS   67000  AK-102
# 1        2      Arati Banne   Solapur      SE   56000  AB-304
# 2        3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3        4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4        5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5        6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6        7    Piyush Sawant    Mumbai      SE   89000      PS
# 7        8     Umesh Thorat      Pune      SE   67000  UT-102
# 8        9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9       10    Supriya Gurav      Pune      SE   90000  SG-100
# 10      11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df.shape
# Out:
# (11, 6)

# %%
df.dtypes
# Out:
# Sr. No     int64
# Name      object
# Place     object
# Post      object
# Salary     int64
# Code      object
# dtype: object

# %%
df.columns
# Out:
# Index(['Sr. No', 'Name', 'Place ', 'Post', 'Salary', 'Code'], dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 df.rows
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
df.ndim
# Out:
# 2

# %%
df.rename('Sr. no':'Sr_no,'Place ':'Place')
# Out:
#   Input In [14]
#     df.rename('Sr. no':'Sr_no,'Place ':'Place')
#                       ^
# SyntaxError: invalid syntax

# %%
df = df.rename(columns={'Sr. No':'Sr_No','Place ':'Place'})

# %%
df.columns
# Out:
# Index(['Sr_No', 'Name', 'Place', 'Post', 'Salary', 'Code'], dtype='object')

# %%
df
# Out:
#     Sr_No             Name     Place    Post  Salary    Code
# 0       1    Akshay Bankar      Pune      DS   67000  AK-102
# 1       2      Arati Banne   Solapur      SE   56000  AB-304
# 2       3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3       4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4       5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5       6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6       7    Piyush Sawant    Mumbai      SE   89000      PS
# 7       8     Umesh Thorat      Pune      SE   67000  UT-102
# 8       9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9      10    Supriya Gurav      Pune      SE   90000  SG-100
# 10     11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df[['Name','Salary']]
# Out:
#                Name  Salary
# 0     Akshay Bankar   67000
# 1       Arati Banne   56000
# 2      Dipak Sawant   78000
# 3     Ganesh Rakate   80000
# 4   Harshala Gondal   45000
# 5      Kuldip Muley  120000
# 6     Piyush Sawant   89000
# 7      Umesh Thorat   67000
# 8     Vaibhav Ladge   87000
# 9     Supriya Gurav   90000
# 10    Shital Shelar   80000

# %%
df[['Sr_No','Name','Place','Salary']]
# Out:
#     Sr_No             Name     Place  Salary
# 0       1    Akshay Bankar      Pune   67000
# 1       2      Arati Banne   Solapur   56000
# 2       3     Dipak Sawant  Kolhapur   78000
# 3       4    Ganesh Rakate    Sangli   80000
# 4       5  Harshala Gondal    Sangli   45000
# 5       6     Kuldip Muley      Beed  120000
# 6       7    Piyush Sawant    Mumbai   89000
# 7       8     Umesh Thorat      Pune   67000
# 8       9    Vaibhav Ladge  Kolhapur   87000
# 9      10    Supriya Gurav      Pune   90000
# 10     11    Shital Shelar     Karad   80000

# %%
df[['Code','Salary','Place']]
# Out:
#       Code  Salary     Place
# 0   AK-102   67000      Pune
# 1   AB-304   56000   Solapur
# 2   DS-100   78000  Kolhapur
# 3   GR-450   80000    Sangli
# 4   HG-232   45000    Sangli
# 5   KM-333  120000      Beed
# 6       PS   89000    Mumbai
# 7   UT-102   67000      Pune
# 8   VL-102   87000  Kolhapur
# 9   SG-100   90000      Pune
# 10  SS-222   80000     Karad

# %%
np.array(df[['Sr_No','Code','Salary','Place']])
# Out:
# array([[1, 'AK-102', 67000, 'Pune'],
#        [2, 'AB-304', 56000, 'Solapur'],
#        [3, 'DS-100', 78000, 'Kolhapur'],
#        [4, 'GR-450', 80000, 'Sangli'],
#        [5, 'HG-232', 45000, 'Sangli'],
#        [6, 'KM-333', 120000, 'Beed'],
#        [7, 'PS', 89000, 'Mumbai'],
#        [8, 'UT-102', 67000, 'Pune'],
#        [9, 'VL-102', 87000, 'Kolhapur'],
#        [10, 'SG-100', 90000, 'Pune'],
#        [11, 'SS-222', 80000, 'Karad']], dtype=object)

# %%
np.array(df[['Name','Salary']])
# Out:
# array([['Akshay Bankar', 67000],
#        ['Arati Banne', 56000],
#        ['Dipak Sawant', 78000],
#        ['Ganesh Rakate', 80000],
#        ['Harshala Gondal', 45000],
#        ['Kuldip Muley', 120000],
#        ['Piyush Sawant', 89000],
#        ['Umesh Thorat', 67000],
#        ['Vaibhav Ladge', 87000],
#        ['Supriya Gurav', 90000],
#        ['Shital Shelar', 80000]], dtype=object)

# %%
np.array(df[['Code','Salary']])
# Out:
# array([['AK-102', 67000],
#        ['AB-304', 56000],
#        ['DS-100', 78000],
#        ['GR-450', 80000],
#        ['HG-232', 45000],
#        ['KM-333', 120000],
#        ['PS', 89000],
#        ['UT-102', 67000],
#        ['VL-102', 87000],
#        ['SG-100', 90000],
#        ['SS-222', 80000]], dtype=object)

# %%
df.Salary.mean()
# Out:
# 78090.90909090909

# %%
df.Salary.median()
# Out:
# 80000.0

# %%
df.Salary.mode()
# Out:
# 0    67000
# 1    80000
# Name: Salary, dtype: int64

# %%
round(df.Salary.mean(),1)
# Out:
# 78090.9

# %%
df.Place.value_counts()
# Out:
# Pune        3
# Kolhapur    2
# Sangli      2
# Solapur     1
# Beed        1
# Mumbai      1
# Karad       1
# Name: Place, dtype: int64

# %%
df.Code.value_counts()
# Out:
# AK-102    1
# AB-304    1
# DS-100    1
# GR-450    1
# HG-232    1
# KM-333    1
# PS        1
# UT-102    1
# VL-102    1
# SG-100    1
# SS-222    1
# Name: Code, dtype: int64

# %%
df.Place.value_counts().plot(kind='bar',color = 'r')
plt.title('Placewise total count')
plt.xlabel('-------------------------------PLACE--------------------------------------->')
plt.ylabel('----------------------COUNT---------------------->')
plt.autoscale()
plt.grid()
plt.Arrow(2,3,0.1,0.1)

# %%
df.query('Place'==Pune)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 df.query('Place'==Pune)
#
# NameError: name 'Pune' is not defined

# %%
df.query('Place == "Pune"')
# Out:
#    Sr_No           Name Place Post  Salary    Code
# 0      1  Akshay Bankar  Pune   DS   67000  AK-102
# 7      8   Umesh Thorat  Pune   SE   67000  UT-102
# 9     10  Supriya Gurav  Pune   SE   90000  SG-100

# %%
df.query("Name == 'Kuldip Muley'", "Place == 'Pune'", "Post == HR")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [76], in <cell line: 1>()
# ----> 1 df.query("Name == 'Kuldip Muley'", "Place == 'Pune'", "Post == HR")
#
# TypeError: query() takes from 2 to 3 positional arguments but 4 were given

# %%
df
# Out:
#     Sr_No             Name     Place    Post  Salary    Code
# 0       1    Akshay Bankar      Pune      DS   67000  AK-102
# 1       2      Arati Banne   Solapur      SE   56000  AB-304
# 2       3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3       4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4       5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5       6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6       7    Piyush Sawant    Mumbai      SE   89000      PS
# 7       8     Umesh Thorat      Pune      SE   67000  UT-102
# 8       9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9      10    Supriya Gurav      Pune      SE   90000  SG-100
# 10     11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df.query("Place == 'Pune'")
# Out:
#    Sr_No           Name Place Post  Salary    Code
# 0      1  Akshay Bankar  Pune   DS   67000  AK-102
# 7      8   Umesh Thorat  Pune   SE   67000  UT-102
# 9     10  Supriya Gurav  Pune   SE   90000  SG-100

# %%
df.query("Name == 'Umesh Thorat'")
# Out:
#    Sr_No          Name Place Post  Salary    Code
# 7      8  Umesh Thorat  Pune   SE   67000  UT-102

# %%
df
# Out:
#     Sr_No             Name     Place    Post  Salary    Code
# 0       1    Akshay Bankar      Pune      DS   67000  AK-102
# 1       2      Arati Banne   Solapur      SE   56000  AB-304
# 2       3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3       4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4       5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5       6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6       7    Piyush Sawant    Mumbai      SE   89000      PS
# 7       8     Umesh Thorat      Pune      SE   67000  UT-102
# 8       9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9      10    Supriya Gurav      Pune      SE   90000  SG-100
# 10     11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df.query("Code=='SS-222'")
# Out:
#     Sr_No           Name  Place    Post  Salary    Code
# 10     11  Shital Shelar  Karad  Tester   80000  SS-222

# %%
df.query("Post=='SE'")
# Out:
#    Sr_No           Name    Place Post  Salary    Code
# 1      2    Arati Banne  Solapur   SE   56000  AB-304
# 6      7  Piyush Sawant   Mumbai   SE   89000      PS
# 7      8   Umesh Thorat     Pune   SE   67000  UT-102
# 9     10  Supriya Gurav     Pune   SE   90000  SG-100

# %%
df.query("Salary == 80000")
# Out:
#     Sr_No           Name   Place    Post  Salary    Code
# 3       4  Ganesh Rakate  Sangli      HR   80000  GR-450
# 10     11  Shital Shelar   Karad  Tester   80000  SS-222

# %%
df.query("Sr_No==9")
# Out:
#    Sr_No           Name     Place    Post  Salary    Code
# 8      9  Vaibhav Ladge  Kolhapur  Tester   87000  VL-102

# %%
df.query("Place=='Pune'").to_csv('Punekr.csv',index=False)

# %%
df.query('Place=="Pune"').to_csv('Punekar.csv',index=False) #As file of Punekar was created initially it can't be overwritten
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [99], in <cell line: 1>()
# ----> 1 df.query('Place=="Pune"').to_csv('Punekar.csv',index=False)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3540 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3542 formatter = DataFrameFormatter(
#    3543     frame=df,
#    3544     header=header,
#    (...)
#    3548     decimal=decimal,
#    3549 )
# -> 3551 return DataFrameRenderer(formatter).to_csv(
#    3552     path_or_buf,
#    3553     line_terminator=line_terminator,
#    3554     sep=sep,
#    3555     encoding=encoding,
# ...

# %%
df.query("Post == 'SE'").to_csv('Salary1.csv',index=True)

# %%
df
# Out:
#     Sr_No             Name     Place    Post  Salary    Code
# 0       1    Akshay Bankar      Pune      DS   67000  AK-102
# 1       2      Arati Banne   Solapur      SE   56000  AB-304
# 2       3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3       4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4       5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5       6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6       7    Piyush Sawant    Mumbai      SE   89000      PS
# 7       8     Umesh Thorat      Pune      SE   67000  UT-102
# 8       9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9      10    Supriya Gurav      Pune      SE   90000  SG-100
# 10     11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df.query("Place=='Pune' or Place== 'Sangli' or Place == 'Karad'")
# Out:
#     Sr_No             Name   Place    Post  Salary    Code
# 0       1    Akshay Bankar    Pune      DS   67000  AK-102
# 3       4    Ganesh Rakate  Sangli      HR   80000  GR-450
# 4       5  Harshala Gondal  Sangli      DS   45000  HG-232
# 7       8     Umesh Thorat    Pune      SE   67000  UT-102
# 9      10    Supriya Gurav    Pune      SE   90000  SG-100
# 10     11    Shital Shelar   Karad  Tester   80000  SS-222

# %%
df.query("Place=='Pune' and Place=='Karad'")
# Out:
# Empty DataFrame
# Columns: [Sr_No, Name, Place, Post, Salary, Code]
# Index: []

# %%
df.query("Place== 'Pune' or Place== 'Sangli'").Salary
# Out:
# 0    67000
# 3    80000
# 4    45000
# 7    67000
# 9    90000
# Name: Salary, dtype: int64

# %%
df.query("Place=='Pune' or Code=='AK-102' or Code=='SS-222'")
# Out:
#     Sr_No           Name  Place    Post  Salary    Code
# 0       1  Akshay Bankar   Pune      DS   67000  AK-102
# 7       8   Umesh Thorat   Pune      SE   67000  UT-102
# 9      10  Supriya Gurav   Pune      SE   90000  SG-100
# 10     11  Shital Shelar  Karad  Tester   80000  SS-222

# %%
df.query("Place== 'Pune' or Code== 'SS-222' or Salary== 80000").Salary.mean()
# Out:
# 76800.0

# %%
df

# %%
df.Salary.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df.Salary.mean()
#
# NameError: name 'df' is not defined

# %%
df.query("Place== 'Pune' or Code== 'SS-222' or Salary== 80000").Salary.median()
# Out:
# 80000.0

# %%
df.query("Place== 'Pune' or Code== 'SS-222' or Salary== 80000").Salary.mode()
# Out:
# 0    67000
# 1    80000
# Name: Salary, dtype: int64

# %%
df.query("Place== 'Pune' or Code== 'SS-222' or Salary== 80000").Salary.min()
# Out:
# 67000

# %%
df.query("Place== 'Pune' or Code== 'SS-222' or Salary== 80000").Salary.max()
# Out:
# 90000

# %%
df[df.Salary == df.Salary.max()]
# Out:
#    Sr_No          Name Place Post  Salary    Code
# 5      6  Kuldip Muley  Beed  CEO  120000  KM-333

# %%
df[df.Salary < df.Salary.max()]
# Out:
#     Sr_No             Name     Place    Post  Salary    Code
# 0       1    Akshay Bankar      Pune      DS   67000  AK-102
# 1       2      Arati Banne   Solapur      SE   56000  AB-304
# 2       3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3       4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4       5  Harshala Gondal    Sangli      DS   45000  HG-232
# 6       7    Piyush Sawant    Mumbai      SE   89000      PS
# 7       8     Umesh Thorat      Pune      SE   67000  UT-102
# 8       9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9      10    Supriya Gurav      Pune      SE   90000  SG-100
# 10     11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df[df.Salary== df.Salary.min()]
# Out:
#    Sr_No             Name   Place Post  Salary    Code
# 4      5  Harshala Gondal  Sangli   DS   45000  HG-232

# %%
df[df.Salary < df.Salary.mean()]
# Out:
#    Sr_No             Name     Place   Post  Salary    Code
# 0      1    Akshay Bankar      Pune     DS   67000  AK-102
# 1      2      Arati Banne   Solapur     SE   56000  AB-304
# 2      3     Dipak Sawant  Kolhapur  Admin   78000  DS-100
# 4      5  Harshala Gondal    Sangli     DS   45000  HG-232
# 7      8     Umesh Thorat      Pune     SE   67000  UT-102

# %%
df[df.Salary > df.Salary.mean()]
# Out:
#     Sr_No           Name     Place    Post  Salary    Code
# 3       4  Ganesh Rakate    Sangli      HR   80000  GR-450
# 5       6   Kuldip Muley      Beed     CEO  120000  KM-333
# 6       7  Piyush Sawant    Mumbai      SE   89000      PS
# 8       9  Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9      10  Supriya Gurav      Pune      SE   90000  SG-100
# 10     11  Shital Shelar     Karad  Tester   80000  SS-222

# %%
df.sort_values(by="Post")
# Out:
#     Sr_No             Name     Place    Post  Salary    Code
# 2       3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 5       6     Kuldip Muley      Beed     CEO  120000  KM-333
# 0       1    Akshay Bankar      Pune      DS   67000  AK-102
# 4       5  Harshala Gondal    Sangli      DS   45000  HG-232
# 3       4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 1       2      Arati Banne   Solapur      SE   56000  AB-304
# 6       7    Piyush Sawant    Mumbai      SE   89000      PS
# 7       8     Umesh Thorat      Pune      SE   67000  UT-102
# 9      10    Supriya Gurav      Pune      SE   90000  SG-100
# 8       9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 10     11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df.sort_values(by='Salary')
# Out:
#     Sr_No             Name     Place    Post  Salary    Code
# 4       5  Harshala Gondal    Sangli      DS   45000  HG-232
# 1       2      Arati Banne   Solapur      SE   56000  AB-304
# 0       1    Akshay Bankar      Pune      DS   67000  AK-102
# 7       8     Umesh Thorat      Pune      SE   67000  UT-102
# 2       3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3       4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 10     11    Shital Shelar     Karad  Tester   80000  SS-222
# 8       9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 6       7    Piyush Sawant    Mumbai      SE   89000      PS
# 9      10    Supriya Gurav      Pune      SE   90000  SG-100
# 5       6     Kuldip Muley      Beed     CEO  120000  KM-333

# %%
df.sort_values(by='Code')
# Out:
#     Sr_No             Name     Place    Post  Salary    Code
# 1       2      Arati Banne   Solapur      SE   56000  AB-304
# 0       1    Akshay Bankar      Pune      DS   67000  AK-102
# 2       3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3       4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4       5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5       6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6       7    Piyush Sawant    Mumbai      SE   89000      PS
# 9      10    Supriya Gurav      Pune      SE   90000  SG-100
# 10     11    Shital Shelar     Karad  Tester   80000  SS-222
# 7       8     Umesh Thorat      Pune      SE   67000  UT-102
# 8       9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102

# %%
import numpy as np #numeric operations
import pandas as pd #data analysis
import matplotlib.pyplot as plt # data visulization

# load dataset using pandas
df = pd.read_excel('batch__19.xlsx')
df #dataframe
# Out:
#     Sr. No             Name    Place     Post  Salary    Code
# 0        1    Akshay Bankar      Pune      DS   67000  AK-102
# 1        2      Arati Banne   Solapur      SE   56000  AB-304
# 2        3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3        4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4        5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5        6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6        7    Piyush Sawant    Mumbai      SE   89000      PS
# 7        8     Umesh Thorat      Pune      SE   67000  UT-102
# 8        9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9       10    Supriya Gurav      Pune      SE   90000  SG-100
# 10      11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df
# Out:
#     Sr. No             Name    Place     Post  Salary    Code
# 0        1    Akshay Bankar      Pune      DS   67000  AK-102
# 1        2      Arati Banne   Solapur      SE   56000  AB-304
# 2        3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3        4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4        5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5        6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6        7    Piyush Sawant    Mumbai      SE   89000      PS
# 7        8     Umesh Thorat      Pune      SE   67000  UT-102
# 8        9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9       10    Supriya Gurav      Pune      SE   90000  SG-100
# 10      11    Shital Shelar     Karad  Tester   80000  SS-222

# %%
df.sort_values(by ="Place ")
# Out:
#     Sr. No             Name    Place     Post  Salary    Code
# 5        6     Kuldip Muley      Beed     CEO  120000  KM-333
# 10      11    Shital Shelar     Karad  Tester   80000  SS-222
# 2        3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 8        9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 6        7    Piyush Sawant    Mumbai      SE   89000      PS
# 0        1    Akshay Bankar      Pune      DS   67000  AK-102
# 7        8     Umesh Thorat      Pune      SE   67000  UT-102
# 9       10    Supriya Gurav      Pune      SE   90000  SG-100
# 3        4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4        5  Harshala Gondal    Sangli      DS   45000  HG-232
# 1        2      Arati Banne   Solapur      SE   56000  AB-304

# %%
df.sort_values()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 df.sort_values(by='ascending')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6313, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6309 elif len(by):
#    6310     # len(by) == 1
#    6312     by = by[0]
# -> 6313     k = self._get_label_or_level_values(by, axis=axis)
# ...

# %%
df.sort_values(by='Sr. No')
# Out:
#     Sr. No             Name    Place     Post  Salary    Code
# 0        1    Akshay Bankar      Pune      DS   67000  AK-102
# 1        2      Arati Banne   Solapur      SE   56000  AB-304
# 2        3     Dipak Sawant  Kolhapur   Admin   78000  DS-100
# 3        4    Ganesh Rakate    Sangli      HR   80000  GR-450
# 4        5  Harshala Gondal    Sangli      DS   45000  HG-232
# 5        6     Kuldip Muley      Beed     CEO  120000  KM-333
# 6        7    Piyush Sawant    Mumbai      SE   89000      PS
# 7        8     Umesh Thorat      Pune      SE   67000  UT-102
# 8        9    Vaibhav Ladge  Kolhapur  Tester   87000  VL-102
# 9       10    Supriya Gurav      Pune      SE   90000  SG-100
# 10      11    Shital Shelar     Karad  Tester   80000  SS-222
