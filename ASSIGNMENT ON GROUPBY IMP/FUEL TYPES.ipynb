# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
rv = pd.read_csv('Fuel type Registration of Vehicles.csv')
rv[:2]
# Out:
#    Month  CNG Only    DIESEL  Diesel/Hybrid  Electric (BOV)  LPG Only   \
# 0  Apr-17     1,825  1,93,689          3,412           5,063        89
# 1  May-17     1,918  1,82,173          4,172           7,080       160
#
#      Petrol  Petrol/CNG  Petrol/Hybrid  Petrol/LPG   Ethanol  Not Applicable
# 0  14,32,174      16,879            108       4,941       1.0           6,784
# 1  15,10,907      17,968             88       5,198       1.0           7,403

# %%
rv[:2]
# Out:
#    Month  CNG Only    DIESEL  Diesel/Hybrid  Electric (BOV)  LPG Only   \
# 0  Apr-17     1,825  1,93,689          3,412           5,063        89
# 1  May-17     1,918  1,82,173          4,172           7,080       160
#
#      Petrol  Petrol/CNG  Petrol/Hybrid  Petrol/LPG   Ethanol  Not Applicable
# 0  14,32,174      16,879            108       4,941       1.0           6,784
# 1  15,10,907      17,968             88       5,198       1.0           7,403

# %% [raw]
# rv.columns

# %%
rv.columns
# Out:
# Index(['Month ', 'CNG Only ', 'DIESEL ', 'Diesel/Hybrid ', 'Electric (BOV) ',
#        'LPG Only ', 'Petrol ', 'Petrol/CNG ', 'Petrol/Hybrid ', 'Petrol/LPG ',
#        'Ethanol ', 'Not Applicable '],
#       dtype='object')

# %%
rv.columns.str.replace(' ','')
rv[:2]
# Out:
#    Month  CNG Only    DIESEL  Diesel/Hybrid  Electric (BOV)  LPG Only   \
# 0  Apr-17     1,825  1,93,689          3,412           5,063        89
# 1  May-17     1,918  1,82,173          4,172           7,080       160
#
#      Petrol  Petrol/CNG  Petrol/Hybrid  Petrol/LPG   Ethanol  Not Applicable
# 0  14,32,174      16,879            108       4,941       1.0           6,784
# 1  15,10,907      17,968             88       5,198       1.0           7,403

# %%
rv.columns
# Out:
# Index(['Month ', 'CNG Only ', 'DIESEL ', 'Diesel/Hybrid ', 'Electric (BOV) ',
#        'LPG Only ', 'Petrol ', 'Petrol/CNG ', 'Petrol/Hybrid ', 'Petrol/LPG ',
#        'Ethanol ', 'Not Applicable '],
#       dtype='object')

# %%
rv.head(2)
# Out:
#    Month  CNG Only    DIESEL  Diesel/Hybrid  Electric (BOV)  LPG Only   \
# 0  Apr-17     1,825  1,93,689          3,412           5,063        89
# 1  May-17     1,918  1,82,173          4,172           7,080       160
#
#      Petrol  Petrol/CNG  Petrol/Hybrid  Petrol/LPG   Ethanol  Not Applicable
# 0  14,32,174      16,879            108       4,941       1.0           6,784
# 1  15,10,907      17,968             88       5,198       1.0           7,403

# %%
rv.rename(columns={'Month ':'Month', 'CNG Only ':'CNGOnly', 'DIESEL ':'DIESEL', 'Diesel/Hybrid ':'Diesel_Hybrid','Electric_(BOV)':'Electric_BOV',
       'LPG Only ':'LPGOnly', 'Petrol ':'Petrol', 'Petrol/CNG ':'Petrol_CNG', 'Petrol/Hybrid ':'Petrol_Hybrid', 'Petrol/LPG ':'Petrol_LPG',
       'Ethanol ':'Ethanol', 'Not Applicable ':'NotApplicable'},inplace=True)

# %%
rv.rename(coulmns={})

# %%
rv.columns
# Out:
# Index(['Month', 'CNGOnly', 'DIESEL', 'Diesel_Hybrid', 'Electric_BOV',
#        'LPGOnly', 'Petrol', 'Petrol_CNG', 'Petrol_Hybrid', 'Petrol_LPG',
#        'Ethanol', 'NotApplicable', 'year'],
#       dtype='object')

# %%
rv.columns
# Out:
# Index(['Month ', 'CNG Only ', 'DIESEL ', 'Diesel/Hybrid ', 'Electric (BOV) ',
#        'LPG Only ', 'Petrol ', 'Petrol/CNG ', 'Petrol/Hybrid ', 'Petrol/LPG ',
#        'Ethanol ', 'Not Applicable '],
#       dtype='object')

# %%
rv['year']=rv.Month.str.split('-',expand=True)[1]
rv['year'][9]
# Out:
# '18'

# %%
rv.columns
rv[:2]
# Out:
#     Month CNGOnly    DIESEL Diesel_Hybrid Electric (BOV)  LPGOnly     Petrol  \
# 0  Apr-17   1,825  1,93,689         3,412           5,063      89  14,32,174
# 1  May-17   1,918  1,82,173         4,172           7,080     160  15,10,907
#
#   Petrol_CNG Petrol_Hybrid Petrol_LPG  Ethanol NotApplicable year
# 0     16,879           108      4,941      1.0         6,784   17
# 1     17,968            88      5,198      1.0         7,403   17

# %%
rv.year.value_counts().sort_index()
# Out:
# 17     9
# 18    12
# 19    12
# 20    12
# 21    12
# 22     3
# Name: year, dtype: int64

# %%
rv['Month']=rv.Month.str.split('-',expand=True)[0]
rv['Month'].unique().sort()

# %%
rv[:2]
# Out:
#     Month CNGOnly  DIESEL Diesel_Hybrid Electric (BOV)  LPGOnly     Petrol  \
# 0  Apr-17   1,825  193689         3,412           5,063      89  14,32,174
# 1  May-17   1,918  182173         4,172           7,080     160  15,10,907
#
#   Petrol_CNG Petrol_Hybrid Petrol_LPG  Ethanol NotApplicable year
# 0     16,879           108      4,941      1.0         6,784   17
# 1     17,968            88      5,198      1.0         7,403   17

# %%
rvp = rv.count()

# %%
rvp.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
rv[:3]
# Out:
#   Month CNGOnly    DIESEL Diesel_Hybrid Electric (BOV)  LPGOnly     Petrol  \
# 0   Apr   1,825  1,93,689         3,412           5,063      89  14,32,174
# 1   May   1,918  1,82,173         4,172           7,080     160  15,10,907
# 2   Jun   2,352  1,94,894         4,717           7,508     218  14,23,800
#
#   Petrol_CNG Petrol_Hybrid Petrol_LPG  Ethanol NotApplicable year
# 0     16,879           108      4,941      1.0         6,784   17
# 1     17,968            88      5,198      1.0         7,403   17
# 2     18,768           123      6,000      1.0         6,784   17

# %% [markdown]
# # year wise count of vehicles of CNG ONLY <=2000

# %%
list(rv.groupby(['CNGOnly']))
# Out:
# [('1,532',
#     Month CNGOnly    DIESEL Diesel_Hybrid Electric (BOV)  LPGOnly     Petrol  \
#   4   Aug   1,532  1,85,968         3,201           9,174     643  12,41,005
#
#     Petrol_CNG Petrol_Hybrid Petrol_LPG  Ethanol NotApplicable year
#   4     20,652            31      5,891      NaN         5,359   17  ),
#  ('1,745',
#     Month CNGOnly    DIESEL Diesel_Hybrid Electric (BOV)  LPGOnly     Petrol  \
#   5   Sep   1,745  1,96,562         3,440           7,795     532  12,62,629
#
#     Petrol_CNG Petrol_Hybrid Petrol_LPG  Ethanol NotApplicable year
#   5     25,744            36      6,189      NaN         6,264   17  ),
#  ('1,787',
#     Month CNGOnly    DIESEL Diesel_Hybrid Electric (BOV)  LPGOnly     Petrol  \
#   8   Dec   1,787  1,99,253         3,570           9,054     458  12,67,974
#
#     Petrol_CNG Petrol_Hybrid Petrol_LPG  Ethanol NotApplicable year
#   8     29,560            19      5,959     11.0         8,602   17  ),
#  ('1,825',
# ...

# %%
#pd.to_numeric(rv.CNGOnly,errors='coerce')
rv.CNGOnly.str.replace(',','')
# Out:
# 0      1825
# 1      1918
# 2      2352
# 3      2081
# 4      1532
# 5      1745
# 6      2316
# 7      2332
# 8      1787
# 9      2552
# 10     2348
# 11     2428
# 12     2678
# 13     2401
# 14     2113
# 15     2032
# 16     2100
# 17     2361
# 18     2777
# 19     2538
# 20     2626
# 21     2972
# 22     2478
# 23     2744
# 24     2848
# 25     2607
# 26     2214
# 27     2504
# 28     2492
# 29     2283
# 30     2565
# 31     2738
# 32     2071
# 33     2903
# 34     3328
# 35     6730
# 36     1868
# 37      186
# 38     1831
# 39     2410
# 40     2841
# 41     4054
# 42     4670
# 43     5805
# 44     4751
# 45     5928
# 46    10821
# 47    13411
# 48     8355
# 49     2202
# 50     7022
# 51    13754
# 52    16091
# 53    20676
# 54    21582
# 55    22331
# 56    21525
# 57    23059
# 58    20480
# 59    24807
# Name: CNGOnly, dtype: object

# %%
rv['CNGOnly']=pd.to_numeric(rv.CNGOnly.str.replace(',',''),errors='coerce')
rv['CNGOnly']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 rv['CNGOnly']=pd.to_numeric(rv.CNGOnly.str.replace(',',''),errors='coerce')
#       2 rv['CNGOnly'][:3]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# ...

# %%
rv.CNGOnly.unique()
# Out:
# array([ 1825,  1918,  2352,  2081,  1532,  1745,  2316,  2332,  1787,
#         2552,  2348,  2428,  2678,  2401,  2113,  2032,  2100,  2361,
#         2777,  2538,  2626,  2972,  2478,  2744,  2848,  2607,  2214,
#         2504,  2492,  2283,  2565,  2738,  2071,  2903,  3328,  6730,
#         1868,   186,  1831,  2410,  2841,  4054,  4670,  5805,  4751,
#         5928, 10821, 13411,  8355,  2202,  7022, 13754, 16091, 20676,
#        21582, 22331, 21525, 23059, 20480, 24807], dtype=int64)

# %%
rv.columns
# Out:
# Index(['Month', 'CNGOnly', 'DIESEL', 'Diesel_Hybrid', 'Electric (BOV) ',
#        'LPGOnly', 'Petrol', 'Petrol_CNG', 'Petrol_Hybrid', 'Petrol_LPG',
#        'Ethanol', 'NotApplicable', 'year'],
#       dtype='object')

# %%
rv['DIESEL'][9]
# Out:
# '2,40,793'

# %%
rv['Petrol_LPG']=pd.to_numeric(rv.Petrol_LPG.str.replace(',',''),errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 rv['Petrol_LPG']=pd.to_numeric(rv.Petrol_LPG.str.replace(',',''),errors='coerce')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# ...

# %%
rv.tail(5)
# Out:
#    Month  CNGOnly    DIESEL Diesel_Hybrid Electric (BOV)  LPGOnly     Petrol  \
# 55   Nov    22331  1,37,209             2          42,098   1,662  15,88,245
# 56   Dec    21525  1,56,868             2          50,915   1,399  13,02,529
# 57   Jan    23059  1,57,663             3          48,169   1,241  11,74,882
# 58   Feb    20480  1,51,020             4          54,046   1,018  11,13,704
# 59   Mar    24807  1,87,624             3          77,199   1,276  12,87,888
#
#    Petrol_CNG Petrol_Hybrid  Petrol_LPG  Ethanol NotApplicable year
# 55     17,016        11,714         548      NaN         4,699   21
# 56     18,756         9,919         496      NaN         5,882   21
# 57     26,727        10,809         485      NaN         4,805   22
# 58     30,363         9,359         315      NaN         5,174   22
# 59     34,965         8,072         524      1.0         6,131   22

# %% [markdown]
# # Yearly sales distribution of each type of vehicle

# %%
list(rv.groupby('year'))
# Out:
# [('17',
#     Month  CNGOnly    DIESEL Diesel_Hybrid Electric (BOV)  LPGOnly     Petrol  \
#   0   Apr     1825  1,93,689         3,412           5,063      89  14,32,174
#   1   May     1918  1,82,173         4,172           7,080     160  15,10,907
#   2   Jun     2352  1,94,894         4,717           7,508     218  14,23,800
#   3   Jul     2081  1,96,529         4,161           9,031     521  13,09,851
#   4   Aug     1532  1,85,968         3,201           9,174     643  12,41,005
#   5   Sep     1745  1,96,562         3,440           7,795     532  12,62,629
#   6   Oct     2316  2,12,104         4,548           7,715     212  17,56,702
#   7   Nov     2332  2,44,725         5,023          10,303     422  18,98,134
#   8   Dec     1787  1,99,253         3,570           9,054     458  12,67,974
#
#     Petrol_CNG Petrol_Hybrid  Petrol_LPG  Ethanol NotApplicable year
#   0     16,879           108        4941      1.0         6,784   17
# ...

# %%
mp=rv[['Month','Petrol','year']]
mp
# Out:
#    Month     Petrol year
# 0    Apr  14,32,174   17
# 1    May  15,10,907   17
# 2    Jun  14,23,800   17
# 3    Jul  13,09,851   17
# 4    Aug  12,41,005   17
# 5    Sep  12,62,629   17
# 6    Oct  17,56,702   17
# 7    Nov  18,98,134   17
# 8    Dec  12,67,974   17
# 9    Jan  14,95,758   18
# 10   Feb  13,59,532   18
# 11   Mar  15,78,613   18
# 12   Apr  15,54,402   18
# 13   May  16,96,579   18
# 14   Jun  15,37,263   18
# 15   Jul  15,32,951   18
# 16   Aug  14,08,636   18
# 17   Sep  13,76,823   18
# 18   Oct  14,75,062   18
# 19   Nov  18,70,869   18
# 20   Dec  16,08,323   18
# 21   Jan  14,99,611   19
# 22   Feb  13,35,981   19
# 23   Mar  14,79,944   19
# 24   Apr  14,61,234   19
# 25   May  15,53,034   19
# 26   Jun  14,54,150   19
# 27   Jul  15,18,595   19
# 28   Aug  13,69,957   19
# 29   Sep  12,67,515   19
# 30   Oct  15,89,529   19
# 31   Nov  19,64,346   19
# 32   Dec  14,06,598   19
# 33   Jan  14,53,790   20
# 34   Feb  14,42,204   20
# 35   Mar  19,81,769   20
# ...

# %%
plt.xlabel('MONTH_WISE',fontsize=15)
plt.figure(figsize=(29,29)
sns.stripplot(data=mp,x='Month',y='Petrol')
# Out:
#   Input In [45]
#     sns.stripplot(data=mp,x='Month',y='Petrol')
#     ^
# SyntaxError: invalid syntax

# %%
rv.isna().sum()
# Out:
# Month               0
# CNGOnly             0
# DIESEL              0
# Diesel_Hybrid       3
# Electric (BOV)      0
# LPGOnly             0
# Petrol              0
# Petrol_CNG          0
# Petrol_Hybrid       0
# Petrol_LPG          0
# Ethanol            38
# NotApplicable       0
# year                0
# dtype: int64

# %%
rv[rv.year=='17']
# Out:
#   Month  CNGOnly    DIESEL Diesel_Hybrid Electric (BOV)  LPGOnly     Petrol  \
# 0   Apr     1825  1,93,689         3,412           5,063      89  14,32,174
# 1   May     1918  1,82,173         4,172           7,080     160  15,10,907
# 2   Jun     2352  1,94,894         4,717           7,508     218  14,23,800
# 3   Jul     2081  1,96,529         4,161           9,031     521  13,09,851
# 4   Aug     1532  1,85,968         3,201           9,174     643  12,41,005
# 5   Sep     1745  1,96,562         3,440           7,795     532  12,62,629
# 6   Oct     2316  2,12,104         4,548           7,715     212  17,56,702
# 7   Nov     2332  2,44,725         5,023          10,303     422  18,98,134
# 8   Dec     1787  1,99,253         3,570           9,054     458  12,67,974
#
#   Petrol_CNG Petrol_Hybrid  Petrol_LPG  Ethanol NotApplicable year
# 0     16,879           108        4941      1.0         6,784   17
# 1     17,968            88        5198      1.0         7,403   17
# ...

# %%
rv[:3]
# Out:
#   Month  CNGOnly    DIESEL Diesel_Hybrid Electric (BOV)  LPGOnly     Petrol  \
# 0   Apr     1825  1,93,689         3,412           5,063      89  14,32,174
# 1   May     1918  1,82,173         4,172           7,080     160  15,10,907
# 2   Jun     2352  1,94,894         4,717           7,508     218  14,23,800
#
#   Petrol_CNG Petrol_Hybrid  Petrol_LPG  Ethanol NotApplicable year
# 0     16,879           108        4941      1.0         6,784   17
# 1     17,968            88        5198      1.0         7,403   17
# 2     18,768           123        6000      1.0         6,784   17

# %%
rv['DIESEL']=pd.to_numeric(rv.DIESEL.str.replace(',',''),errors='coerce')
rv['DIESEL']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 rv['DIESEL']=pd.to_numeric(rv.DIESEL.str.replace(',',''),errors='coerce')
#       2 rv['DIESEL'][:4]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# ...

# %%
rv.columns
# Out:
# Index(['Month', 'CNGOnly', 'DIESEL', 'Diesel_Hybrid', 'Electric (BOV) ',
#        'LPGOnly', 'Petrol', 'Petrol_CNG', 'Petrol_Hybrid', 'Petrol_LPG',
#        'Ethanol', 'NotApplicable'],
#       dtype='object')

# %%
rv.columns
# Out:
# Index(['Month', 'CNGOnly', 'DIESEL', 'Diesel_Hybrid', 'Electric_BOV',
#        'LPGOnly', 'Petrol', 'Petrol_CNG', 'Petrol_Hybrid', 'Petrol_LPG',
#        'Ethanol', 'NotApplicable', 'year'],
#       dtype='object')

# %%
rv[:1]
# Out:
#     Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0  Apr-17     1825  193689         3412.0          5063       89  1432174
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol NotApplicable year
# 0       16879            108        4941      1.0         6,784   17

# %%
rv['year']=pd.to_numeric(rv.year.str.replace(',',''),errors='coerce')
rv['year']
# Out:
# 0     17
# 1     17
# 2     17
# 3     17
# 4     17
# 5     17
# 6     17
# 7     17
# 8     17
# 9     18
# 10    18
# 11    18
# 12    18
# 13    18
# 14    18
# 15    18
# 16    18
# 17    18
# 18    18
# 19    18
# 20    18
# 21    19
# 22    19
# 23    19
# 24    19
# 25    19
# 26    19
# 27    19
# 28    19
# 29    19
# 30    19
# 31    19
# 32    19
# 33    20
# 34    20
# 35    20
# 36    20
# 37    20
# 38    20
# 39    20
# 40    20
# 41    20
# 42    20
# 43    20
# 44    20
# 45    21
# 46    21
# 47    21
# 48    21
# 49    21
# 50    21
# 51    21
# 52    21
# 53    21
# 54    21
# 55    21
# 56    21
# 57    22
# 58    22
# 59    22
# Name: year, dtype: int64

# %%
rv[:3]
# Out:
#     Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0  Apr-17     1825  193689         3412.0          5063       89  1432174
# 1  May-17     1918  182173         4172.0          7080      160  1510907
# 2  Jun-17     2352  194894         4717.0          7508      218  1423800
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17
# 2       18768            123        6000      1.0           6784    17

# %%
d=rv

# %%
d[:3]
# Out:
#     Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0  Apr-17     1825  193689         3412.0          5063       89  1432174
# 1  May-17     1918  182173         4172.0          7080      160  1510907
# 2  Jun-17     2352  194894         4717.0          7508      218  1423800
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17
# 2       18768            123        6000      1.0           6784    17

# %%
d.to_csv('dfuel.csv')

# %%
d[:2]
# Out:
#     Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0  Apr-17     1825  193689         3412.0          5063       89  1432174
# 1  May-17     1918  182173         4172.0          7080      160  1510907
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17

# %%
d['Month']=d.Month.str.split('-',expand=True)[0]
d['Month'][:3]
# Out:
# 0    Apr
# 1    May
# 2    Jun
# Name: Month, dtype: object

# %%
d[:2]
# Out:
#   Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0   Apr     1825  193689         3412.0          5063       89  1432174
# 1   May     1918  182173         4172.0          7080      160  1510907
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17

# %%
d.Month.value_counts()
# Out:
# Apr    5
# May    5
# Jun    5
# Jul    5
# Aug    5
# Sep    5
# Oct    5
# Nov    5
# Dec    5
# Jan    5
# Feb    5
# Mar    5
# Name: Month, dtype: int64

# %% [markdown]
# ### Month wise data

# %%
d[:1]
# Out:
#   Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0   Apr     1825  193689         3412.0          5063       89  1432174
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17

# %%
y_18=list(d.groupby(['year']))[1][1]

# %%
y_17=list(d.groupby(['year']))[0][1]
y_17
# Out:
#   Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0   Apr     1825  193689         3412.0          5063       89  1432174
# 1   May     1918  182173         4172.0          7080      160  1510907
# 2   Jun     2352  194894         4717.0          7508      218  1423800
# 3   Jul     2081  196529         4161.0          9031      521  1309851
# 4   Aug     1532  185968         3201.0          9174      643  1241005
# 5   Sep     1745  196562         3440.0          7795      532  1262629
# 6   Oct     2316  212104         4548.0          7715      212  1756702
# 7   Nov     2332  244725         5023.0         10303      422  1898134
# 8   Dec     1787  199253         3570.0          9054      458  1267974
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17
# ...

# %%
y_19=list(d.groupby(['year']))[2][1]

# %%
y_20=list(d.groupby(['year']))[3][1]

# %%
y_21=list(d.groupby(['year']))[4][1]

# %%
y_22=list(d.groupby(['year']))[5][1]

# %%
y_22
# Out:
#    Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 57   Jan    23059  157663            3.0         48169     1241  1174882
# 58   Feb    20480  151020            4.0         54046     1018  1113704
# 59   Mar    24807  187624            3.0         77199     1276  1287888
#
#     Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 57       26727          10809         485      NaN           4805    22
# 58       30363           9359         315      NaN           5174    22
# 59       34965           8072         524      1.0           6131    22

# %%
y_17
# Out:
#   Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0   Apr     1825  193689         3412.0          5063       89  1432174
# 1   May     1918  182173         4172.0          7080      160  1510907
# 2   Jun     2352  194894         4717.0          7508      218  1423800
# 3   Jul     2081  196529         4161.0          9031      521  1309851
# 4   Aug     1532  185968         3201.0          9174      643  1241005
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17
# 2       18768            123        6000      1.0           6784    17
# 3       18069             30        5427      1.0           6897    17
# 4       20652             31        5891      NaN           5359    17

# %%
y_18[:3]
# Out:
#    Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 9    Jan     2552  240793         4996.0          8888      229  1495758
# 10   Feb     2348  220106         4400.0          7453      268  1359532
# 11   Mar     2428  248625         5042.0          7830      329  1578613
#
#     Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 9        37337             34        7423      6.0           8673    18
# 10       34433             38        8162      NaN           6099    18
# 11       34379             64        8793      NaN           6601    18

# %% [markdown]
# # Monthwise distribution of sale of each type of vehicle

# %%
y_17.columns.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Index(['Month', 'CNGOnly', 'DIESEL', 'Diesel_Hybrid', 'Electric_BOV',
#        'LPGOnly', 'Petrol', 'Petrol_CNG', 'Petrol_Hybrid', 'Petrol_LPG',
#        'Ethanol', 'NotApplicable', 'year'],
#       dtype='object')>

# %%
y_17=y_17.drop(columns=['NotApplicable', 'year'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [159], in <cell line: 1>()
# ----> 1 y_17=y_17.drop(columns=['NotApplicable', 'year'])
#       2 y_17
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
# ...

# %%
sns.barplot(data=y_17,x='Month',y='CNGOnly')
# Out:
# <AxesSubplot:xlabel='Month', ylabel='CNGOnly'>

# %%
y_17[:2]
# Out:
#   Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0   Apr     1825  193689         3412.0          5063       89  1432174
# 1   May     1918  182173         4172.0          7080      160  1510907
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol
# 0       16879            108        4941      1.0
# 1       17968             88        5198      1.0

# %%
sns.stripplot(data=d,x='year',y='CNGOnly',hue='Month')
# Out:
# <AxesSubplot:xlabel='year', ylabel='CNGOnly'>

# %%
plt.figure(figsize=(25,25))
sns.barplot(data=d,x='year',y='CNGOnly',hue='Month')
plt.xlabel('YEAR',fontsize=25)
plt.ylabel('CNG',fontsize=25)
plt.show()

# %%
d[:2]
# Out:
#   Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0   Apr     1825  193689         3412.0          5063       89  1432174
# 1   May     1918  182173         4172.0          7080      160  1510907
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17

# %%
plt.figure(figsize=(25,25))
sns.barplot(data=d,x='year',y='Petrol',hue='Month')
plt.xlabel('YEAR',fontsize=25)
plt.ylabel('PETROL',fontsize=25)
plt.show()

# %%
d[:2]
# Out:
#   Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0   Apr     1825  193689         3412.0          5063       89  1432174
# 1   May     1918  182173         4172.0          7080      160  1510907
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17

# %%
plt.figure(figsize=(25,25))
sns.barplot(data=d,x='Month',y='Diesel_Hybrid',hue='year')
plt.xlabel('YEAR',fontsize=25)
plt.ylabel('Diesel_Hybrid',fontsize=25)
plt.show()

# %%
d.plot(subplots=True,figsize=(15,15),layout=(4,3))
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
d.plot.bar(stacked=True,figsize=(125,125))
# Out:
# <AxesSubplot:>

# %%
d.plot.bar(subplots=True,figsize=(25,125))
# Out:
# array([<AxesSubplot:title={'center':'CNGOnly'}>,
#        <AxesSubplot:title={'center':'DIESEL'}>,
#        <AxesSubplot:title={'center':'Diesel_Hybrid'}>,
#        <AxesSubplot:title={'center':'Electric_BOV'}>,
#        <AxesSubplot:title={'center':'LPGOnly'}>,
#        <AxesSubplot:title={'center':'Petrol'}>,
#        <AxesSubplot:title={'center':'Petrol_CNG'}>,
#        <AxesSubplot:title={'center':'Petrol_Hybrid'}>,
#        <AxesSubplot:title={'center':'Petrol_LPG'}>,
#        <AxesSubplot:title={'center':'Ethanol'}>,
#        <AxesSubplot:title={'center':'NotApplicable'}>,
#        <AxesSubplot:title={'center':'year'}>], dtype=object)

# %%
d.DIESEL.plot(kind='pie',figsize=(25,25))
# Out:
# <AxesSubplot:ylabel='DIESEL'>

# %%
d[:2]
# Out:
#   Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0   Apr     1825  193689         3412.0          5063       89  1432174
# 1   May     1918  182173         4172.0          7080      160  1510907
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17

# %%
y=d.groupby('year')
x=(y['CNGOnly'].sum())
x
# Out:
# year
# 17     17888
# 18     28954
# 19     30516
# 20     41377
# 21    163698
# 22     68346
# Name: CNGOnly, dtype: int64

# %%
x.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
d.columns
# Out:
# Index(['Month', 'CNGOnly', 'DIESEL', 'Diesel_Hybrid', 'Electric_BOV',
#        'LPGOnly', 'Petrol', 'Petrol_CNG', 'Petrol_Hybrid', 'Petrol_LPG',
#        'Ethanol', 'NotApplicable', 'year'],
#       dtype='object')

# %%
y1=d.groupby('year')
x1=(y1['DIESEL'].sum())
x1
# Out:
# year
# 17    1805897
# 18    2696263
# 19    2503189
# 20    1748468
# 21    1754975
# 22     496307
# Name: DIESEL, dtype: int64

# %%
x1.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# # Month wise total sales and distribution

# %%
x2=d.groupby('Month')
y2=x2['Petrol'].sum()
y2
# Out:
# Month
# Apr    5794075
# Aug    6204498
# Dec    7216873
# Feb    6530281
# Jan    7004525
# Jul    6667220
# Jun    6364026
# Mar    7725516
# May    5414798
# Nov    8983347
# Oct    7170475
# Sep    6152137
# Name: Petrol, dtype: int64

# %%
y2.plot.bar(sort_columns=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 y2.plot.bar(sort_columns=False)
#
# NameError: name 'y2' is not defined

# %%
import pandas as pd
d=pd.read_csv('dfuel.csv')
d.columns
# Out:
# Index(['Unnamed: 0', 'Month', 'CNGOnly', 'DIESEL', 'Diesel_Hybrid',
#        'Electric_BOV', 'LPGOnly', 'Petrol', 'Petrol_CNG', 'Petrol_Hybrid',
#        'Petrol_LPG', 'Ethanol', 'NotApplicable', 'year'],
#       dtype='object')

# %%
d.drop(columns=['Unnamed: 0'],inplace=True)

# %%
d[:2]
# Out:
#     Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0  Apr-17     1825  193689         3412.0          5063       89  1432174
# 1  May-17     1918  182173         4172.0          7080      160  1510907
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17

# %%
d.isna().sum()
# Out:
# Month             0
# CNGOnly           0
# DIESEL            0
# Diesel_Hybrid     3
# Electric_BOV      0
# LPGOnly           0
# Petrol            0
# Petrol_CNG        0
# Petrol_Hybrid     0
# Petrol_LPG        0
# Ethanol          38
# NotApplicable     0
# year              0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si=SimpleImputer()
si
# Out:
# SimpleImputer()

# %%
d[['Diesel_Hybrid','Ethanol']]=si.fit_transform(d[['Diesel_Hybrid','Ethanol']])
d[['Diesel_Hybrid','Ethanol']][:2]
# Out:
#    Diesel_Hybrid  Ethanol
# 0         3412.0      1.0
# 1         4172.0      1.0

# %%
import seaborn as sns

# %%
sns.pairplot(data=d)

# %%
#diesel vs petrol,vs petrol_cng vs petrol_lpg
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
d.columns
# Out:
# Index(['Month', 'CNGOnly', 'DIESEL', 'Diesel_Hybrid', 'Electric_BOV',
#        'LPGOnly', 'Petrol', 'Petrol_CNG', 'Petrol_Hybrid', 'Petrol_LPG',
#        'Ethanol', 'NotApplicable', 'year'],
#       dtype='object')

# %%
y = d[['Petrol','Petrol_CNG','Petrol_LPG']]
y[:2]
# Out:
#     Petrol  Petrol_CNG  Petrol_LPG
# 0  1432174       16879        4941
# 1  1510907       17968        5198

# %%
x1= d[['DIESEL']]
x1[:2]
# Out:
#    DIESEL
# 0  193689
# 1  182173

# %%
lr.fit(x1,y1)
# Out:
# LinearRegression()

# %%
X_t = x1.head()
X_t
# Out:
#    DIESEL
# 0  193689
# 1  182173
# 2  194894
# 3  196529
# 4  185968

# %%
y_pred=lr.predict(x1.head())
y_pred
# Out:
# array([[1411833.34953841],
#        [1346759.19776814],
#        [1418642.51529763],
#        [1427881.5078423 ],
#        [1368203.83183971]])

# %%
y[:5]
# Out:
#     Petrol  Petrol_CNG  Petrol_LPG
# 0  1432174       16879        4941
# 1  1510907       17968        5198
# 2  1423800       18768        6000
# 3  1309851       18069        5427
# 4  1241005       20652        5891

# %%
lr.predict([[933334]])
# Out:
# C:\Users\Rakesh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[5591389.70470687]])

# %%
y1=d[['Petrol']]
y1[:3]
# Out:
#     Petrol
# 0  1432174
# 1  1510907
# 2  1423800

# %%
lr.score(x1,y1)*100
# Out:
# 76.11101236810465

# %%
lr.fit(x1,y1)
# Out:
# LinearRegression()

# %%
lr.predict(X_t)
# Out:
# array([[1411833.34953841],
#        [1346759.19776814],
#        [1418642.51529763],
#        [1427881.5078423 ],
#        [1368203.83183971]])

# %%
y1[:5]
# Out:
#     Petrol
# 0  1432174
# 1  1510907
# 2  1423800
# 3  1309851
# 4  1241005

# %%
d.columns
# Out:
# Index(['Month', 'CNGOnly', 'DIESEL', 'Diesel_Hybrid', 'Electric_BOV',
#        'LPGOnly', 'Petrol', 'Petrol_CNG', 'Petrol_Hybrid', 'Petrol_LPG',
#        'Ethanol', 'NotApplicable', 'year'],
#       dtype='object')

# %%
sns.boxplot(x='DIESEL',data=d)
# Out:
# <AxesSubplot:xlabel='DIESEL'>

# %%
sns.boxplot(data=d,x='Petrol')
# Out:
# <AxesSubplot:xlabel='Petrol'>

# %%
import numpy as np
print(np.where(d['Petrol']<500000))
print(np.where(d['DIESEL']<53000))
# Out:
# (array([36, 37, 49], dtype=int64),)
# (array([36, 37, 49], dtype=int64),)

# %%
d.drop(index=37,inplace=True)

# %%
d
# Out:
#      Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0   Apr-17     1825  193689    3412.000000          5063       89  1432174
# 1   May-17     1918  182173    4172.000000          7080      160  1510907
# 2   Jun-17     2352  194894    4717.000000          7508      218  1423800
# 3   Jul-17     2081  196529    4161.000000          9031      521  1309851
# 4   Aug-17     1532  185968    3201.000000          9174      643  1241005
# 5   Sep-17     1745  196562    3440.000000          7795      532  1262629
# 6   Oct-17     2316  212104    4548.000000          7715      212  1756702
# 7   Nov-17     2332  244725    5023.000000         10303      422  1898134
# 8   Dec-17     1787  199253    3570.000000          9054      458  1267974
# 9   Jan-18     2552  240793    4996.000000          8888      229  1495758
# 10  Feb-18     2348  220106    4400.000000          7453      268  1359532
# ...

# %%
lr
# Out:
# LinearRegression()

# %%
x1[:2]
# Out:
#    DIESEL
# 0  193689
# 1  182173

# %%
y1[:2]
# Out:
#     Petrol
# 0  1432174
# 1  1510907

# %%
lr.fit(x1,y1)
# Out:
# LinearRegression()

# %%
lr.predict(X_t)
# Out:
# array([[1411833.34953841],
#        [1346759.19776814],
#        [1418642.51529763],
#        [1427881.5078423 ],
#        [1368203.83183971]])

# %%
y1.head()
# Out:
#     Petrol
# 0  1432174
# 1  1510907
# 2  1423800
# 3  1309851
# 4  1241005

# %%
d[:2]
# Out:
#     Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0  Apr-17     1825  193689         3412.0          5063       89  1432174
# 1  May-17     1918  182173         4172.0          7080      160  1510907
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17

# %%
l_pet=d[['LPGOnly','Petrol_Hybrid']]
l_pet[:2]
# Out:
#    LPGOnly  Petrol_Hybrid
# 0       89            108
# 1      160             88

# %%
sns.boxplot(data=l_pet,x='Petrol_Hybrid')
# Out:
# <AxesSubplot:xlabel='Petrol_Hybrid'>

# %%
sns.boxplot(data=l_pet,x='LPGOnly')
# Out:
# <AxesSubplot:xlabel='LPGOnly'>

# %%
from sklearn.linear_model import LinearRegression
lr2=LinearRegression()

# %%
X=d[['LPGOnly']]
y=d[['Petrol_Hybrid']]

# %%
lr2.fit(X,y)
# Out:
# LinearRegression()

# %%
X__t=X.head(15)
X__t
# Out:
#     LPGOnly
# 0        89
# 1       160
# 2       218
# 3       521
# 4       643
# 5       532
# 6       212
# 7       422
# 8       458
# 9       229
# 10      268
# 11      329
# 12      479
# 13      375
# 14      270

# %%
y_act=y.head(15)
y_act
# Out:
#     Petrol_Hybrid
# 0             108
# 1              88
# 2             123
# 3              30
# 4              31
# 5              36
# 6              35
# 7              22
# 8              19
# 9              34
# 10             38
# 11             64
# 12             75
# 13             52
# 14             89

# %%
y_pred=lr2.predict(X__t)

# %%
lr2.coef_
# Out:
# array([[6.97664896]])

# %%
lr2.intercept_
# Out:
# array([1017.61159836])

# %% [markdown]
# # SPLITTING ELEMENTS OF POPULATION

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.9)

# %%
import matplotlib.pyplot as plt
print(plt.scatter(X_train,y_train))

# %%
y_train[:2]
# Out:
#     Petrol_Hybrid
# 58           9359
# 46          10583

# %%
X_train[:2]
# Out:
#     LPGOnly
# 58     1018
# 46      887

# %%
y[:2]
# Out:
#    Petrol_Hybrid
# 0            108
# 1             88

# %%
lr2
# Out:
# LinearRegression()

# %%
reg = LinearRegression()
reg
# Out:
# LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X_test)
y_pred
# Out:
# array([[ 6107.87135257],
#        [ 5196.70533486],
#        [  797.71529856],
#        [ 2119.65288163],
#        [ 2425.86441217],
#        [12837.05645054]])

# %%
y_test
# Out:
#     Petrol_Hybrid
# 47          12006
# 24           6697
# 30           8716
# 25           6864
# 10             38
# 55          11714

# %%
d[:2]
# Out:
#     Month  CNGOnly  DIESEL  Diesel_Hybrid  Electric_BOV  LPGOnly   Petrol  \
# 0  Apr-17     1825  193689         3412.0          5063       89  1432174
# 1  May-17     1918  182173         4172.0          7080      160  1510907
#
#    Petrol_CNG  Petrol_Hybrid  Petrol_LPG  Ethanol  NotApplicable  year
# 0       16879            108        4941      1.0           6784    17
# 1       17968             88        5198      1.0           7403    17

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)*100
# Out:
# -34.463929862375586
